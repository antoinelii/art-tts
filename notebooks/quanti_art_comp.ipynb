# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

import joblib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
import soundfile as sf

from configs.params_v1 import reorder_feats
from paths import DATA_DIR

import utils_ema.ema_dataset

from scipy.stats import pearsonr
from metrics import normalized_dtw_score
from utils import plot_art_14

from tqdm import tqdm

# %%
from text.converters import arpabet2ipa
from utils_dataset.mspka import mspka2ipa
from utils_dataset.pb2007 import pb20072ipa
from utils_dataset.mngu0 import mngu02ipa

lj_ipa_set = set(arpabet2ipa.values())

mspka_ipa = set(mspka2ipa.values())
extra_mspka_ipa = mspka_ipa - lj_ipa_set

pb2007_ipa = set(pb20072ipa.values())
extra_pb_ipa = pb2007_ipa - lj_ipa_set

mngu0_ipa = set(mngu02ipa.values())
extra_mngu0_ipa = mngu0_ipa - lj_ipa_set

dataset = "mocha_timit"
speakers = ["fsew0", "faet0", "ffes0", "maps0", "mjjn0", "msak0"]
mocha_ipa = []

version = "v1_1"
ckpt_name = "grad_3000"
for speaker in speakers:
    analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
    phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
    spk_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

    for i, row in spk_df.iterrows():
        sample_id = row["filestem"]
        phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
        for start, end, phnm in phnm3:
            if phnm not in mocha_ipa:
                mocha_ipa.append(phnm)
                
mocha_ipa = set(mocha_ipa)
extra_mocha_ipa = mocha_ipa - lj_ipa_set

dataset_2_extra_ipa = {
    "MSPKA_EMA_ita": extra_mspka_ipa,
    "pb2007": extra_pb_ipa,
    "MNGU0": extra_mngu0_ipa,
    "mocha_timit": extra_mocha_ipa,
}

# %%
versions_grads = {"v1" : ["grad_200", "grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"],
                  "v1_1": ["grad_200", "grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"],
                  "v1_" : ["grad_4750"],
                  "v2": ["grad_200", "grad_1000", "grad_2000", "grad_3000", "grad_4000"],
                  "v3": ["grad_200", "grad_1000", "grad_2000", "grad_3000", "grad_4000"],#, "grad_5000"],
                  "v4": ["grad_200", "grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"],
                  "v2_phnmtext": ["grad_1000", "grad_2000"],
                  "v4_phnmtext": ["grad_1000", "grad_2000"],
                  "v5": ["grad_1000", "grad_2000", "grad_3000"],
                  "v5_preblock": ["grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"]
                  }

score_cols = ['pcc_no_dtw', 'dtw_gt_enc', 'dtw_gt_dec', 'dtw_gt_sparc', 'dtw_sparc_enc', 'dtw_sparc_dec',
              'pcc_gt_enc', 'pcc_gt_dec', 'pcc_gt_sparc', 'pcc_sparc_enc', 'pcc_sparc_dec',
              'pred_rel_gap', 'enc_dtw_distortion', 'dec_dtw_distortion', 'sparc_dtw_distortion']

# %%
import utils_ema.ema_dataset

dataset = "pb2007"
processed_data_dir = DATA_DIR / dataset / "processed_data"
spkmetadata_filename = "1.0_speaker_metadata_100Hz.joblib"
# get the PCC scores of SPARC and other metadata for each sentence
spkmeta = joblib.load(processed_data_dir / f"spk1/{spkmetadata_filename}")
ids = spkmeta.list_valid_ids()
pcc_scores = []
filestems = []
splits = []
durations = []
for id in ids:
    sentencemeta = spkmeta.sentence_info[id]
    filestems.append(sentencemeta.filestem)
    splits.append(sentencemeta.split)
    pcc_scores.append(sentencemeta.PCC_score)
    durations.append(sentencemeta.duration)

summary_df = pd.DataFrame({
                            "filestem": filestems,
                            "split": splits,
                            "pcc": pcc_scores,
                            "duration": durations
                        })
if dataset == "pb2007":
    sentence_types = [spkmeta.sentence_info[id].sentence_type for id in ids]
    summary_df["sentence_types"] = sentence_types

sentence_filestems = list(summary_df[summary_df["sentence_types"] == "sentence"]["filestem"])

def get_specific_summary(dataset, speaker, version, ckpt_name, do_extra_ipa=False, remove_invalid=True):
    analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
    short_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")
    if dataset == "pb2007":
        short_df = short_df[short_df["filestem"].isin(sentence_filestems)]
    #add count of extra ipa phnms that were absent during the train
    if do_extra_ipa:
        extra_ipa = dataset_2_extra_ipa[dataset]
        phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
        short_df["extra_ipa"] = 0

        for i, row in short_df.iterrows():
            sample_id = row["filestem"]
            phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
            for start, end, phnm in phnm3:
                if phnm in extra_ipa:
                    short_df.loc[i, "extra_ipa"] += 1
    if remove_invalid:
        original_len = len(short_df)
        if 'valid_enc' in short_df.columns:
            short_df = short_df[short_df["valid_enc"]]
        if 'valid_dec' in short_df.columns:
            short_df = short_df[short_df["valid_dec"]]
            #print(f"Removed {original_len - len(short_df)} invalid samples for {dataset} {speaker} {version} {ckpt_name}")
    return short_df

def create_dataset_summary(dataset, speakers, versions):
    dataset_summary = []
    for speaker in speakers:
        analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
        for version in versions:
            ckpt_names = versions_grads[version]
            for ckpt_name in ckpt_names:
                row = {
                    "speaker": speaker,
                    "version": version,
                    "ckpt_name": ckpt_name
                }
                #short_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")
                short_df = get_specific_summary(dataset, speaker, version, ckpt_name, do_extra_ipa=False)
                row["speaker"] = speaker
                row["version"] = version
                row["ckpt_name"] = ckpt_name
                short_means = short_df.describe().loc["mean"]
                for colname, v in zip(short_means.keys(), short_means.values):
                    row[colname] = v
                dataset_summary.append(row)

    dataset_summary = pd.DataFrame(dataset_summary)
    dataset_summary.rename(columns={"ckpt_name" : "epoch"}, inplace=True)
    dataset_summary["epoch"] = dataset_summary["epoch"].str.replace("grad_", "").astype(int)
    dataset_summary.drop(columns=["pcc", "duration"], inplace=True)
    return dataset_summary

def plot_speaker_scores(speaker, dataset, versions, dataset_summary, ref="gt", show_enc=False):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax = ax.flatten()
    spk_summary = dataset_summary[dataset_summary["speaker"] == speaker]
    print(f"Speaker {speaker} pcc_gt_sparc with/without dtw {spk_summary["pcc_gt_sparc"].values[0]:.3f} {spk_summary["pcc_no_dtw"].values[0]:.3f}")
    for i, version in enumerate(versions):
        version_summary = spk_summary[spk_summary["version"] == version]
        version_summary = version_summary.sort_values(by="epoch")
        if show_enc:
            ax[0].plot(version_summary["epoch"], version_summary[f"pcc_{ref}_enc"],marker="v", c=colors[i], linestyle="--")
        ax[0].plot(version_summary["epoch"], version_summary[f"pcc_{ref}_dec"],marker="o", c=colors[i], linestyle="-", label=f"{version} dec")
        ax[0].set_xlabel("Checkpoint Name")
        ax[0].set_ylabel("PCC")
        ax[0].set_title(f"Speaker {speaker} - {dataset}")
        ax[0].legend()
        ax[0].grid()
    ax[0].grid()
    
    print(f"Speaker {speaker} dtw_gt_sparc {spk_summary["dtw_gt_sparc"].values[0]:.3f}")
    for i, version in enumerate(versions):
        version_summary = spk_summary[spk_summary["version"] == version]
        version_summary = version_summary.sort_values(by="epoch")
        if show_enc:
            ax[1].plot(version_summary["epoch"], version_summary[f"dtw_{ref}_enc"],marker="v", c=colors[i], linestyle="--")
        ax[1].plot(version_summary["epoch"], version_summary[f"dtw_{ref}_dec"],marker="o", c=colors[i], linestyle="-", label=f"{version} dec")
        ax[1].set_xlabel("Checkpoint Name")
        ax[1].set_ylabel("DTW")
        ax[1].set_title(f"Speaker {speaker} - {dataset}")
        ax[1].legend()
        ax[1].grid()
    ax[1].grid()
    plt.tight_layout()

# %% [markdown]
# Quantitative evaluation of the arttts generated samples from the SPARC-extracted EMA features with the best and worst PCC score (Careful, may be influenced by the quality ofthe linear transfo. The PCC scores are computed on linearly transformed features (from MNGU0 space to concerned speaker) while the reconstruction takes an MNGU0-space input)
#
# We want to assess how powerful the HiFi GAN is and how much it relies on accurate EMA/articulatory predictions.
#
# We also test the sensitivity to pitch and speaker embedding

# %% [markdown]
# # MSPKA_EMA_ita

# %%
dataset = "MSPKA_EMA_ita"
speakers = ["cnz", "lls", "olm"]
versions = ["v1", "v1_1", "v2", "v3", "v4", "v2_phnmtext", "v4_phnmtext", "v5", "v5_preblock"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
dataset_summary.head()
# Out:
#   speaker version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  dtw_gt_sparc  \
# 0     cnz      v1    200    0.773684    2.518845    2.490771      2.018662
# 1     cnz      v1   1000    0.773684    2.531682    2.482307      2.018662
# 2     cnz      v1   2000    0.773684    2.522390    2.468318      2.018662
# 3     cnz      v1   3000    0.773684    2.513147    2.463830      2.018662
# 4     cnz      v1   4000    0.773684    2.523650    2.466069      2.018662
#
#    dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  pcc_gt_sparc  \
# 0       1.740926       1.714618    0.664259    0.669314      0.805161
# 1       1.766518       1.705736    0.657906    0.669057      0.805161
# 2       1.758295       1.692708    0.658736    0.671259      0.805161
# 3       1.755363       1.696234    0.661866    0.672837      0.805161
# 4       1.773108       1.699452    0.657768    0.670853      0.805161
#
#    pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  enc_dtw_distortion  \
# 0       0.770858       0.772015      0.129589            0.255918
# 1       0.763640       0.773678      0.156571            0.235255
# 2       0.765132       0.776928      0.175881            0.225508
# 3       0.766082       0.775705      0.173749            0.225702
# 4       0.761379       0.774387      0.177459            0.227626
#
#    dec_dtw_distortion  sparc_dtw_distortion
# 0            0.269267              0.093497
# 1            0.250711              0.093497
# 2            0.241761              0.093497
# 3            0.240962              0.093497
# 4            0.242699              0.093497

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
avg_summary = dataset_summary.groupby(["version", "epoch"]).mean(score_cols).reset_index() #average over speakers
avg_summary = avg_summary[["version", "epoch"] + score_cols]

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
col = "pcc_gt_dec"
for version in versions:
    ax[0].plot(avg_summary[avg_summary["version"] == version]["epoch"],
             avg_summary[avg_summary["version"] == version][col],
             marker="o", label=version)
ax[0].set_xlabel("Checkpoint Name")
ax[0].set_ylabel("PCC")
ax[0].set_title(f"Average {col} over speakers for {dataset}")
ax[0].grid()
ax[0].legend()

#plotting mean absolute relative distortion by dtw
width = 0.2  # Bar width
#x = np.arange(len(datasets))  # Dataset positions
mean_scores = []
xs = []
for version in versions:
    means = []
    stds = []
    version_df = avg_summary[avg_summary["version"] == version]
    ckpts = versions_grads[version]
    xs.append(ckpts)
    for ckpt in ckpts:
        means.append(version_df["dec_dtw_distortion"].mean())
    mean_scores.append(means)

for i, version in enumerate(versions):
    x = np.arange(len(xs[i]))  # Update x positions for each version
    ax[1].bar(x + i * width, mean_scores[i], width, label=version, capsize=5)

# Add labels and legend
ax[1].set_xlabel("Checkpoint")
ax[1].set_ylabel("Abs relative distortion")
ax[1].set_title("Mean absolute relative distortion for Each Version Across checkpoint")
ax[1].set_xticks(np.arange(len(xs[0])) + width)
ax[1].set_xticklabels(xs[0])
ax[1].legend()
ax[1].grid(axis="y")

plt.tight_layout()
plt.show()

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]

plot_speaker_scores("cnz", dataset, versions, dataset_summary, ref="gt")
plot_speaker_scores("lls", dataset, versions, dataset_summary, ref="gt")
plot_speaker_scores("olm", dataset, versions, dataset_summary, ref="gt")
# Out:
# Speaker cnz pcc_gt_sparc with/without dtw 0.805 0.774
# Speaker cnz dtw_gt_sparc 2.019
# Speaker lls pcc_gt_sparc with/without dtw 0.673 0.627
# Speaker lls dtw_gt_sparc 2.463
# Speaker olm pcc_gt_sparc with/without dtw 0.782 0.752
# Speaker olm dtw_gt_sparc 2.119

# %%
ckpt_name = "grad_2000"
versions = ["v1_1", "v5", "v5_preblock"]
speaker = "cnz"
versions_dfs = []

for version in versions:
    versions_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],
             labels=versions);
# Out:
# /tmp/ipykernel_284056/2032502021.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],

# %%
ckpt_names = ["grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"]
#ckpt_names = ["grad_1000", "grad_2000", "grad_3000"]
#versions = ["v1_1", "v5", "v5_preblock"]
version = "v1_1"
#version = "v5_preblock"
speaker = "cnz"
ckpt_names_dfs = []

for ckpt_name in ckpt_names:
    ckpt_names_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],
             labels=ckpt_names);
# Out:
# /tmp/ipykernel_284056/950958128.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],

# %%
dataset_summary
# Out:
#    speaker      version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  \
# 0      cnz           v1    200    0.773684    2.518845    2.490771
# 1      cnz           v1   1000    0.773684    2.531682    2.482307
# 2      cnz           v1   2000    0.773684    2.522390    2.468318
# 3      cnz           v1   3000    0.773684    2.513147    2.463830
# 4      cnz           v1   4000    0.773684    2.523650    2.466069
# 5      cnz           v1   5000    0.773684    2.525147    2.470896
# 6      cnz         v1_1    200    0.773684    2.498575    2.476528
# 7      cnz         v1_1   1000    0.773684    2.519580    2.487507
# 8      cnz         v1_1   2000    0.773684    2.516998    2.469781
# 9      cnz         v1_1   3000    0.773684    2.522769    2.469564
# 10     cnz         v1_1   4000    0.773684    2.523616    2.470320
# 11     cnz         v1_1   5000    0.773684    2.519927    2.469168
# 12     cnz           v5   1000    0.773684    2.508789    2.477816
# 13     cnz           v5   2000    0.773684    2.521029    2.471693
# 14     cnz           v5   3000    0.773684    2.517182    2.473007
# 15     cnz  v5_preblock   1000    0.773684    2.583893    2.500242
# 16     cnz  v5_preblock   2000    0.773485    2.573479    2.499315
# 17     cnz  v5_preblock   3000    0.773721    2.576655    2.494719
# 18     cnz  v5_preblock   4000    0.773587    2.567516    2.487326
# 19     cnz  v5_preblock   5000    0.773490    2.561639    2.498733
# 20     lls           v1    200    0.627293    2.756769    2.709748
# 21     lls           v1   1000    0.627293    2.760870    2.688939
# 22     lls           v1   2000    0.627293    2.749097    2.676412
# 23     lls           v1   3000    0.627293    2.746245    2.684592
# 24     lls           v1   4000    0.627293    2.754226    2.683112
# 25     lls           v1   5000    0.627293    2.756375    2.678184
# 26     lls         v1_1    200    0.627293    2.730500    2.699675
# 27     lls         v1_1   1000    0.627293    2.746273    2.699678
# 28     lls         v1_1   2000    0.627293    2.749700    2.682435
# 29     lls         v1_1   3000    0.627293    2.753260    2.683450
# 30     lls         v1_1   4000    0.627293    2.754226    2.684915
# 31     lls         v1_1   5000    0.627293    2.744577    2.678981
# 32     lls           v5   1000    0.627103    2.737736    2.694824
# 33     lls           v5   2000    0.627361    2.749807    2.678912
# 34     lls           v5   3000    0.627293    2.736929    2.673464
# 35     lls  v5_preblock   1000    0.627333    2.803447    2.721620
# 36     lls  v5_preblock   2000    0.627609    2.788670    2.709079
# 37     lls  v5_preblock   3000    0.627273    2.797195    2.711497
# 38     lls  v5_preblock   4000    0.627133    2.794273    2.710185
# 39     lls  v5_preblock   5000    0.627286    2.776780    2.693232
# 40     olm           v1    200    0.751822    2.569338    2.494299
# 41     olm           v1   1000    0.751822    2.593241    2.481868
# 42     olm           v1   2000    0.751822    2.582321    2.472346
# 43     olm           v1   3000    0.751822    2.570556    2.475958
# 44     olm           v1   4000    0.751822    2.575310    2.472275
# 45     olm           v1   5000    0.751822    2.586681    2.476882
# 46     olm         v1_1    200    0.751822    2.531465    2.475772
# 47     olm         v1_1   1000    0.751822    2.565622    2.499290
# 48     olm         v1_1   2000    0.751822    2.564996    2.457257
# 49     olm         v1_1   3000    0.751822    2.558110    2.457007
# 50     olm         v1_1   4000    0.751822    2.565427    2.461747
# 51     olm         v1_1   5000    0.751822    2.549299    2.459834
# 52     olm           v5   1000    0.751822    2.542721    2.482652
# 53     olm           v5   2000    0.751822    2.581141    2.477751
# 54     olm           v5   3000    0.751822    2.565388    2.468346
# 55     olm  v5_preblock   1000    0.751822    2.670588    2.522415
# 56     olm  v5_preblock   2000    0.751822    2.661083    2.513671
# 57     olm  v5_preblock   3000    0.751716    2.669762    2.512357
# 58     olm  v5_preblock   4000    0.751907    2.663239    2.507003
# 59     olm  v5_preblock   5000    0.751822    2.651361    2.503540
#
#     dtw_gt_sparc  dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  \
# 0       2.018662       1.740926       1.714618    0.664259    0.669314
# 1       2.018662       1.766518       1.705736    0.657906    0.669057
# 2       2.018662       1.758295       1.692708    0.658736    0.671259
# 3       2.018662       1.755363       1.696234    0.661866    0.672837
# 4       2.018662       1.773108       1.699452    0.657768    0.670853
# 5       2.018662       1.778423       1.706337    0.658059    0.669660
# 6       2.018662       1.714748       1.701079    0.667983    0.671578
# 7       2.018662       1.756668       1.711435    0.660033    0.665886
# 8       2.018662       1.753783       1.697906    0.660576    0.672091
# 9       2.018662       1.760313       1.696599    0.659428    0.671700
# 10      2.018662       1.765197       1.700797    0.658390    0.671270
# 11      2.018662       1.761511       1.697868    0.659341    0.671677
# 12      2.018662       1.746729       1.709139    0.664256    0.669600
# 13      2.018662       1.770419       1.705210    0.659578    0.670420
# 14      2.018662       1.767550       1.703212    0.659415    0.668981
# 15      2.018662       1.818089       1.715164    0.645247    0.665903
# 16      2.019674       1.810043       1.719741    0.647198    0.664875
# 17      2.017967       1.815646       1.717702    0.646967    0.666484
# 18      2.018609       1.804742       1.709908    0.649568    0.669012
# 19      2.019046       1.802422       1.725666    0.648951    0.662674
# 20      2.463146       1.558789       1.556245    0.527309    0.542372
# 21      2.463146       1.587719       1.550877    0.522178    0.547471
# 22      2.463146       1.579263       1.539387    0.520860    0.545493
# 23      2.463146       1.578194       1.548546    0.521577    0.542418
# 24      2.463146       1.595981       1.552658    0.517692    0.542326
# 25      2.463146       1.602611       1.555442    0.519777    0.545062
# 26      2.463146       1.538989       1.560370    0.534452    0.542051
# 27      2.463146       1.584037       1.568048    0.524428    0.538802
# 28      2.463146       1.584665       1.553453    0.523238    0.545619
# 29      2.463146       1.596778       1.557716    0.520988    0.543848
# 30      2.463146       1.600538       1.559873    0.518155    0.541547
# 31      2.463146       1.593947       1.551680    0.522393    0.544171
# 32      2.463432       1.567275       1.559966    0.529692    0.541508
# 33      2.463162       1.593315       1.559149    0.525472    0.548572
# 34      2.463146       1.588075       1.551857    0.526946    0.546203
# 35      2.462983       1.634607       1.566278    0.509842    0.535723
# 36      2.462003       1.625601       1.565715    0.512944    0.535779
# 37      2.463142       1.629492       1.562813    0.512683    0.538583
# 38      2.464019       1.623333       1.558573    0.513040    0.539057
# 39      2.463027       1.615007       1.565585    0.514495    0.539423
# 40      2.119424       1.692264       1.653236    0.631903    0.653573
# 41      2.119424       1.721081       1.644209    0.620009    0.653687
# 42      2.119424       1.709132       1.632513    0.620495    0.653060
# 43      2.119424       1.706083       1.636082    0.624807    0.653039
# 44      2.119424       1.717386       1.643903    0.622014    0.653177
# 45      2.119424       1.722440       1.643825    0.619750    0.652170
# 46      2.119424       1.676566       1.647773    0.641617    0.656787
# 47      2.119424       1.716707       1.659949    0.626884    0.645494
# 48      2.119424       1.706638       1.637338    0.627272    0.660279
# 49      2.119424       1.708042       1.638137    0.629020    0.659660
# 50      2.119424       1.712783       1.639545    0.625805    0.658136
# 51      2.119424       1.708922       1.638445    0.630908    0.657974
# 52      2.119424       1.701356       1.650539    0.635726    0.651870
# 53      2.119424       1.730384       1.654704    0.621797    0.652396
# 54      2.119424       1.724719       1.656750    0.625383    0.654851
# 55      2.119424       1.763543       1.653024    0.594876    0.642318
# 56      2.119424       1.765337       1.663149    0.597246    0.643707
# 57      2.119951       1.764147       1.662969    0.595213    0.645093
# 58      2.119648       1.756341       1.645980    0.596897    0.646526
# 59      2.119424       1.750746       1.658855    0.597069    0.642376
#
#     pcc_gt_sparc  pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  \
# 0       0.805161       0.770858       0.772015      0.129589
# 1       0.805161       0.763640       0.773678      0.156571
# 2       0.805161       0.765132       0.776928      0.175881
# 3       0.805161       0.766082       0.775705      0.173749
# 4       0.805161       0.761379       0.774387      0.177459
# 5       0.805161       0.760447       0.772560      0.180764
# 6       0.805161       0.775711       0.775444      0.150236
# 7       0.805161       0.764908       0.771356      0.165387
# 8       0.805161       0.766224       0.775937      0.167303
# 9       0.805161       0.764837       0.775891      0.167802
# 10      0.805161       0.764222       0.776011      0.178919
# 11      0.805161       0.764353       0.776042      0.178374
# 12      0.805161       0.768778       0.772944      0.162461
# 13      0.805161       0.762123       0.773025      0.167882
# 14      0.805161       0.762762       0.773656      0.185488
# 15      0.805161       0.752255       0.772940      0.150132
# 16      0.804960       0.754771       0.771288      0.158744
# 17      0.805287       0.753148       0.771861      0.153615
# 18      0.805118       0.755313       0.773436      0.153365
# 19      0.805032       0.756634       0.769075      0.185966
# 20      0.672977       0.718247       0.713114      0.147851
# 21      0.672977       0.709401       0.718168      0.181220
# 22      0.672977       0.708755       0.718637      0.201020
# 23      0.672977       0.709976       0.716668      0.200011
# 24      0.672977       0.703107       0.714728      0.203708
# 25      0.672977       0.702749       0.714831      0.206229
# 26      0.672977       0.725373       0.709944      0.173303
# 27      0.672977       0.708967       0.710271      0.190083
# 28      0.672977       0.708478       0.716050      0.191854
# 29      0.672977       0.703678       0.713536      0.193017
# 30      0.672977       0.702976       0.714019      0.204753
# 31      0.672977       0.703362       0.714935      0.204678
# 32      0.672850       0.716091       0.711570      0.185534
# 33      0.672985       0.707113       0.714005      0.191409
# 34      0.672977       0.707759       0.715040      0.208751
# 35      0.673025       0.694533       0.711295      0.169791
# 36      0.673314       0.697337       0.710872      0.181941
# 37      0.672963       0.696387       0.711904      0.178526
# 38      0.672745       0.699034       0.712801      0.175954
# 39      0.672994       0.701355       0.711673      0.210925
# 40      0.782090       0.727488       0.736862      0.128455
# 41      0.782090       0.718375       0.739571      0.116936
# 42      0.782090       0.720808       0.741465      0.117389
# 43      0.782090       0.722575       0.741114      0.117468
# 44      0.782090       0.718688       0.738095      0.117933
# 45      0.782090       0.717568       0.738928      0.121013
# 46      0.782090       0.733225       0.738001      0.119066
# 47      0.782090       0.719952       0.733122      0.118424
# 48      0.782090       0.723772       0.742430      0.119830
# 49      0.782090       0.722906       0.741929      0.118130
# 50      0.782090       0.722061       0.741673      0.118158
# 51      0.782090       0.722707       0.741225      0.118170
# 52      0.782090       0.726366       0.736572      0.118211
# 53      0.782090       0.715916       0.735084      0.122659
# 54      0.782090       0.717694       0.735348      0.120773
# 55      0.782090       0.704228       0.736867      0.122186
# 56      0.782090       0.704461       0.734600      0.120832
# 57      0.781956       0.703892       0.734759      0.121441
# 58      0.782051       0.706910       0.739240      0.123364
# 59      0.782090       0.707852       0.734295      0.124343
#
#     enc_dtw_distortion  dec_dtw_distortion  sparc_dtw_distortion
# 0             0.255918            0.269267              0.093497
# 1             0.235255            0.250711              0.093497
# 2             0.225508            0.241761              0.093497
# 3             0.225702            0.240962              0.093497
# 4             0.227626            0.242699              0.093497
# 5             0.229949            0.246239              0.093497
# 6             0.238336            0.252867              0.093497
# 7             0.235519            0.249602              0.093497
# 8             0.230528            0.245357              0.093497
# 9             0.229126            0.244270              0.093497
# 10            0.223772            0.239269              0.093497
# 11            0.223179            0.239193              0.093497
# 12            0.235346            0.250247              0.093497
# 13            0.232887            0.246131              0.093497
# 14            0.222437            0.237258              0.093497
# 15            0.238277            0.257937              0.093497
# 16            0.233517            0.253478              0.093197
# 17            0.233513            0.255224              0.093729
# 18            0.235074            0.253802              0.093693
# 19            0.217998            0.236861              0.093637
# 20            0.265513            0.287048              0.111949
# 21            0.242279            0.269262              0.111949
# 22            0.233805            0.260082              0.111949
# 23            0.235352            0.260834              0.111949
# 24            0.236203            0.259445              0.111949
# 25            0.235185            0.264211              0.111949
# 26            0.249667            0.270703              0.111949
# 27            0.246259            0.268248              0.111949
# 28            0.239133            0.262965              0.111949
# 29            0.236742            0.263419              0.111949
# 30            0.233519            0.259241              0.111949
# 31            0.234798            0.258572              0.111949
# 32            0.247547            0.267782              0.112045
# 33            0.242102            0.263017              0.111865
# 34            0.233478            0.256227              0.111949
# 35            0.243521            0.271191              0.111939
# 36            0.240522            0.266601              0.111982
# 37            0.238210            0.266045              0.111972
# 38            0.241750            0.267573              0.111780
# 39            0.224072            0.254244              0.112040
# 40            0.376625            0.398321              0.104217
# 41            0.346289            0.372869              0.104217
# 42            0.332111            0.358383              0.104217
# 43            0.336281            0.360361              0.104217
# 44            0.336731            0.363097              0.104217
# 45            0.339070            0.364588              0.104217
# 46            0.354032            0.378097              0.104217
# 47            0.349915            0.373304              0.104217
# 48            0.341236            0.364917              0.104217
# 49            0.344517            0.367806              0.104217
# 50            0.335165            0.359028              0.104217
# 51            0.334514            0.357181              0.104217
# 52            0.352488            0.371755              0.104217
# 53            0.347519            0.371619              0.104217
# 54            0.334758            0.355492              0.104217
# 55            0.353516            0.381820              0.104217
# 56            0.340762            0.372863              0.104217
# 57            0.344656            0.376461              0.104204
# 58            0.347992            0.376977              0.104113
# 59            0.321070            0.355698              0.104217

# %%
truc = dataset_summary[(dataset_summary["version"] == "v1_1") & (dataset_summary["epoch"] == 2000)]
truc[["speaker", "pcc_gt_dec", "pcc_sparc_dec"]]
print(truc[["pcc_gt_dec"]].mean())
print(truc[["pcc_sparc_dec"]].mean())
# Out:
# pcc_gt_dec    0.625996
# dtype: float64
# pcc_sparc_dec    0.744805
# dtype: float64

# %% [markdown]
# # pb2007

# %%
dataset = "pb2007"
speakers = ["spk1"]
versions = ["v1", "v1_1", "v5", "v5_preblock"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
dataset_summary.head()
# Out:
#   speaker version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  dtw_gt_sparc  \
# 0    spk1      v1    200    0.678072    2.750546    2.750199      2.489608
# 1    spk1      v1   1000    0.678072    2.758073    2.738253      2.489608
# 2    spk1      v1   2000    0.678072    2.752510    2.719253      2.489608
# 3    spk1      v1   3000    0.678072    2.754874    2.730352      2.489608
# 4    spk1      v1   4000    0.678072    2.761639    2.730093      2.489608
#
#    dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  pcc_gt_sparc  \
# 0       1.380698       1.358089    0.592751    0.587923      0.714803
# 1       1.395574       1.338603    0.579942    0.587092      0.714803
# 2       1.390010       1.332536    0.579701    0.589214      0.714803
# 3       1.382811       1.327250    0.579428    0.585397      0.714803
# 4       1.391816       1.329246    0.575825    0.585464      0.714803
#
#    pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  enc_dtw_distortion  \
# 0       0.730881       0.736305      0.123010            0.161387
# 1       0.724547       0.739555      0.142112            0.135393
# 2       0.725978       0.741558      0.166601            0.119701
# 3       0.728415       0.742565      0.161430            0.120314
# 4       0.725233       0.742451      0.170152            0.129863
#
#    dec_dtw_distortion  sparc_dtw_distortion
# 0            0.174209              0.059422
# 1            0.145457              0.059422
# 2            0.139292              0.059422
# 3            0.139659              0.059422
# 4            0.148677              0.059422

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
avg_summary = dataset_summary.groupby(["version", "epoch"]).mean(score_cols).reset_index() #average over speakers
avg_summary = avg_summary[["version", "epoch"] + score_cols]

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
col = "pcc_gt_dec"
for version in versions:
    ax[0].plot(avg_summary[avg_summary["version"] == version]["epoch"],
             avg_summary[avg_summary["version"] == version][col],
             marker="o", label=version)
ax[0].set_xlabel("Checkpoint Name")
ax[0].set_ylabel("PCC")
ax[0].set_title(f"Average {col} over speakers for {dataset}")
ax[0].grid()
ax[0].legend()

#plotting mean absolute relative distortion by dtw
width = 0.2  # Bar width
#x = np.arange(len(datasets))  # Dataset positions
mean_scores = []
xs = []
for version in versions:
    means = []
    stds = []
    version_df = avg_summary[avg_summary["version"] == version]
    ckpts = versions_grads[version]
    xs.append(ckpts)
    for ckpt in ckpts:
        means.append(version_df["dec_dtw_distortion"].mean())
    mean_scores.append(means)

for i, version in enumerate(versions):
    x = np.arange(len(xs[i]))  # Update x positions for each version
    ax[1].bar(x + i * width, mean_scores[i], width, label=version, capsize=5)

# Add labels and legend
ax[1].set_xlabel("Checkpoint")
ax[1].set_ylabel("Abs relative distortion")
ax[1].set_title("Mean absolute relative distortion for Each Version Across checkpoint")
ax[1].set_xticks(np.arange(len(xs[0])) + width)
ax[1].set_xticklabels(xs[0])
ax[1].legend()
ax[1].grid(axis="y")

plt.tight_layout()
plt.show()

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]

plot_speaker_scores("spk1", dataset, versions, dataset_summary, ref="gt")
# Out:
# Speaker spk1 pcc_gt_sparc with/without dtw 0.715 0.678
# Speaker spk1 dtw_gt_sparc 2.490

# %%
ckpt_name = "grad_2000"
versions = ["v1_1", "v5", "v5_preblock"]
speaker = "spk1"
versions_dfs = []

for version in versions:
    versions_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],
             labels=versions);
# Out:
# /tmp/ipykernel_284056/618355705.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],

# %%
ckpt_names = ["grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"]
#ckpt_names = ["grad_1000", "grad_2000", "grad_3000"]
#versions = ["v1_1", "v5", "v5_preblock"]
version = "v1_1"
#version = "v5_preblock"
speaker = "spk1"
ckpt_names_dfs = []

for ckpt_name in ckpt_names:
    ckpt_names_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],
             labels=ckpt_names);
# Out:
# /tmp/ipykernel_284056/386195062.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],

# %%
truc = dataset_summary[(dataset_summary["version"] == "v1_1") & (dataset_summary["epoch"] == 2000)]
truc[["speaker", "pcc_gt_dec", "pcc_sparc_dec"]]
print(truc[["pcc_gt_dec"]].mean())
print(truc[["pcc_sparc_dec"]].mean())
# Out:
# pcc_gt_dec    0.596502
# dtype: float64
# pcc_sparc_dec    0.75399
# dtype: float64

# %% [markdown]
# # mocha_timit

# %%
dataset = "mocha_timit"
speakers = ["faet0", "fsew0", "ffes0", "maps0", "msak0", "mjjn0"]
versions = ["v1", "v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext", "v5", "v5_preblock"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
dataset_summary.head()
# Out:
#   speaker version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  dtw_gt_sparc  \
# 0   faet0      v1    200    0.696867    2.739990    2.728801      2.370316
# 1   faet0      v1   1000    0.696867    2.743114    2.700853      2.370316
# 2   faet0      v1   2000    0.696867    2.746902    2.692747      2.370316
# 3   faet0      v1   3000    0.696867    2.749667    2.692284      2.370316
# 4   faet0      v1   4000    0.696867    2.751257    2.691565      2.370316
#
#    dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  pcc_gt_sparc  \
# 0       1.611422       1.602207    0.593495    0.596915      0.705032
# 1       1.623234       1.558681    0.591143    0.605104      0.705032
# 2       1.624252       1.542381    0.589473    0.608884      0.705032
# 3       1.635877       1.542476    0.589588    0.608947      0.705032
# 4       1.638188       1.543972    0.589025    0.608377      0.705032
#
#    pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  enc_dtw_distortion  \
# 0       0.719817       0.718084      0.133978            0.333720
# 1       0.718039       0.733810      0.130151            0.326923
# 2       0.717176       0.739505      0.127185            0.321497
# 3       0.714835       0.739254      0.126845            0.324037
# 4       0.713316       0.738373      0.128910            0.327047
#
#    dec_dtw_distortion  sparc_dtw_distortion
# 0            0.342065              0.057716
# 1            0.336670              0.057716
# 2            0.328313              0.057716
# 3            0.332822              0.057716
# 4            0.336898              0.057716

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
avg_summary = dataset_summary.groupby(["version", "epoch"]).mean(score_cols).reset_index() #average over speakers
avg_summary = avg_summary[["version", "epoch"] + score_cols]

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
col = "pcc_gt_dec"
for version in versions:
    ax[0].plot(avg_summary[avg_summary["version"] == version]["epoch"],
             avg_summary[avg_summary["version"] == version][col],
             marker="o", label=version)
ax[0].set_xlabel("Checkpoint Name")
ax[0].set_ylabel("PCC")
ax[0].set_title(f"Average {col} over speakers for {dataset}")
ax[0].grid()
ax[0].legend()

#plotting mean absolute relative distortion by dtw
width = 0.2  # Bar width
#x = np.arange(len(datasets))  # Dataset positions
mean_scores = []
xs = []
for version in versions:
    means = []
    stds = []
    version_df = avg_summary[avg_summary["version"] == version]
    ckpts = versions_grads[version]
    xs.append(ckpts)
    for ckpt in ckpts:
        means.append(version_df["dec_dtw_distortion"].mean())
    mean_scores.append(means)

for i, version in enumerate(versions):
    x = np.arange(len(xs[i]))  # Update x positions for each version
    ax[1].bar(x + i * width, mean_scores[i], width, label=version, capsize=5)

# Add labels and legend
ax[1].set_xlabel("Checkpoint")
ax[1].set_ylabel("Abs relative distortion")
ax[1].set_title("Mean absolute relative distortion for Each Version Across checkpoint")
ax[1].set_xticks(np.arange(len(xs[0])) + width)
ax[1].set_xticklabels(xs[0])
ax[1].legend()
ax[1].grid(axis="y")

plt.tight_layout()
plt.show()

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]

for spk in speakers:
    plot_speaker_scores(spk, dataset, versions, dataset_summary, ref="gt")
# Out:
# Speaker faet0 pcc_gt_sparc with/without dtw 0.705 0.697
# Speaker faet0 dtw_gt_sparc 2.370
# Speaker fsew0 pcc_gt_sparc with/without dtw 0.744 0.739
# Speaker fsew0 dtw_gt_sparc 2.259
# Speaker ffes0 pcc_gt_sparc with/without dtw 0.767 0.758
# Speaker ffes0 dtw_gt_sparc 2.184
# Speaker maps0 pcc_gt_sparc with/without dtw 0.746 0.729
# Speaker maps0 dtw_gt_sparc 2.234
# Speaker msak0 pcc_gt_sparc with/without dtw 0.765 0.751
# Speaker msak0 dtw_gt_sparc 2.155
# Speaker mjjn0 pcc_gt_sparc with/without dtw 0.734 0.725
# Speaker mjjn0 dtw_gt_sparc 2.268

# %%
ckpt_name = "grad_2000"
versions = ["v1_1", "v5", "v5_preblock"]
speaker = "faet0"
versions_dfs = []

for version in versions:
    versions_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],
             labels=versions);
# Out:
# /tmp/ipykernel_284056/347230761.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in versions_dfs],

# %%
ckpt_names = ["grad_1000", "grad_2000", "grad_3000", "grad_4000", "grad_5000"]
#ckpt_names = ["grad_1000", "grad_2000", "grad_3000"]
#versions = ["v1_1", "v5", "v5_preblock"]
version = "v1_1"
#version = "v5_preblock"
speaker = "faet0"
ckpt_names_dfs = []

for ckpt_name in ckpt_names:
    ckpt_names_dfs.append(get_specific_summary(dataset, speaker, version, ckpt_name))

plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],
             labels=ckpt_names);
# Out:
# /tmp/ipykernel_284056/1838301735.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df["pcc_gt_dec"].values for df in ckpt_names_dfs],

# %%
truc = dataset_summary[(dataset_summary["version"] == "v1_1") & (dataset_summary["epoch"] == 2000)]
truc[["speaker", "pcc_gt_dec", "pcc_sparc_dec"]]
print(truc[["pcc_gt_dec"]].mean())
print(truc[["pcc_sparc_dec"]].mean())
# Out:
# pcc_gt_dec    0.642489
# dtype: float64
# pcc_sparc_dec    0.757207
# dtype: float64

# %%
# Out:
# pcc_gt_dec    0.642489
# dtype: float64
# pcc_sparc_dec    0.757207
# dtype: float64

# %% [markdown]
# # MNGU0

# %%
df = get_specific_summary("MNGU0", "s1", "v1_1", "grad_3000")[["filestem", "pcc"]]
print(df["pcc"].mean())
print(1.96 * df["pcc"].std()/(df.shape[0]**0.5))
# Out:
# 0.854605064477499
# 0.0030802883698280823

# %%
dataset = "MNGU0"
speakers = ["s1"]
versions = ["v1", "v1_1", "v1_", "v2", "v4", "v2_phnmtext", "v4_phnmtext", "v5", "v5_preblock"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
dataset_summary.head()
# Out:
#   speaker version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  dtw_gt_sparc  \
# 0      s1      v1    200    0.854605    2.550461    2.750706      1.772634
# 1      s1      v1   1000    0.854605    2.567823    2.620048      1.772634
# 2      s1      v1   2000    0.854605    2.571979    2.572175      1.772634
# 3      s1      v1   3000    0.854605    2.579332    2.582614      1.772634
# 4      s1      v1   4000    0.854605    2.581140    2.578950      1.772634
#
#    dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  pcc_gt_sparc  \
# 0       2.232645       2.413423    0.764562    0.761317      0.874679
# 1       2.250609       2.250678    0.763146    0.771524      0.874679
# 2       2.251081       2.197259    0.763456    0.776534      0.874679
# 3       2.263969       2.208045    0.763486    0.776444      0.874679
# 4       2.266069       2.210204    0.761425    0.774602      0.874679
#
#    pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  enc_dtw_distortion  \
# 0       0.803046       0.802378      0.158960            0.361744
# 1       0.801437       0.816951      0.153076            0.351960
# 2       0.802354       0.822339      0.151655            0.349056
# 3       0.800640       0.821878      0.156943            0.355783
# 4       0.798141       0.819382      0.159972            0.358861
#
#    dec_dtw_distortion  sparc_dtw_distortion
# 0            0.371393              0.083072
# 1            0.366175              0.083072
# 2            0.362462              0.083072
# 3            0.370631              0.083072
# 4            0.374388              0.083072

# %%
versions = ["v1", "v1_1","v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]
dataset_summary = create_dataset_summary(dataset, speakers, versions)
avg_summary = dataset_summary.groupby(["version", "epoch"]).mean(score_cols).reset_index() #average over speakers
avg_summary = avg_summary[["version", "epoch"] + score_cols]

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
col = "pcc_gt_dec"
for version in versions:
    ax[0].plot(avg_summary[avg_summary["version"] == version]["epoch"],
             avg_summary[avg_summary["version"] == version][col],
             marker="o", label=version)
ax[0].set_xlabel("Checkpoint Name")
ax[0].set_ylabel("PCC")
ax[0].set_title(f"Average {col} over speakers for {dataset}")
ax[0].grid()
ax[0].legend()

#plotting mean absolute relative distortion by dtw
width = 0.2  # Bar width
#x = np.arange(len(datasets))  # Dataset positions
mean_scores = []
xs = []
for version in versions:
    means = []
    stds = []
    version_df = avg_summary[avg_summary["version"] == version]
    ckpts = versions_grads[version]
    xs.append(ckpts)
    for ckpt in ckpts:
        means.append(version_df["dec_dtw_distortion"].mean())
    mean_scores.append(means)

for i, version in enumerate(versions):
    x = np.arange(len(xs[i]))  # Update x positions for each version
    ax[1].bar(x + i * width, mean_scores[i], width, label=version, capsize=5)

# Add labels and legend
ax[1].set_xlabel("Checkpoint")
ax[1].set_ylabel("Abs relative distortion")
ax[1].set_title("Mean absolute relative distortion for Each Version Across checkpoint")
ax[1].set_xticks(np.arange(len(xs[0])) + width)
ax[1].set_xticklabels(xs[0])
ax[1].legend()
ax[1].grid(axis="y")

plt.tight_layout()
plt.show()

# %%
versions = ["v1", "v1_1", "v5", "v5_preblock"]
#versions = ["v1_1", "v2", "v4", "v2_phnmtext", "v4_phnmtext"]

for spk in speakers:
    plot_speaker_scores(spk, dataset, versions, dataset_summary, ref="gt")
# Out:
# Speaker s1 pcc_gt_sparc with/without dtw 0.875 0.855
# Speaker s1 dtw_gt_sparc 1.773

# %%
mngu0_summary = get_specific_summary(dataset, "s1", "v1_1", "grad_2000")
mngu0_summary.sort_values(by="pcc_gt_dec", ascending=True, inplace=True)
worst = mngu0_summary.iloc[0]
best = mngu0_summary.iloc[-1]

# %%
mngu0_summary
# Out:
#             filestem       pcc  duration  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  \
# 1295   mngu0_s1_0562  0.667281     1.985    0.667281    3.793783    3.952654
# 1306  mngu0_s1_0898b  0.554526     1.175    0.554526    3.675858    3.597478
# 1272  mngu0_s1_0779a  0.718513     1.465    0.718513    4.617867    4.354101
# 1309   mngu0_s1_1189  0.544475     0.995    0.544475    3.274074    3.530118
# 1298  mngu0_s1_0083a  0.650503     1.380    0.650503    3.809970    3.725579
# ...              ...       ...       ...         ...         ...         ...
# 81     mngu0_s1_0960  0.911356     3.235    0.911356    1.948631    1.973486
# 469   mngu0_s1_0794a  0.884288     2.590    0.884288    2.176535    2.180421
# 929   mngu0_s1_0539a  0.841710     1.490    0.841710    2.169299    2.022539
# 492    mngu0_s1_0908  0.882918     2.725    0.882918    1.978256    2.043823
# 523   mngu0_s1_0898a  0.880604     1.870    0.880604    2.292629    1.961919
#
#       dtw_gt_sparc  dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  \
# 1295      2.747793       2.344632       2.451133    0.304073    0.244602
# 1306      2.972517       2.485054       2.854621    0.139572    0.274424
# 1272      2.416056       3.642892       3.382917    0.174767    0.284969
# 1309      2.862297       2.033858       2.672308    0.481525    0.339566
# 1298      2.741257       2.657434       3.219838    0.380828    0.357807
# ...            ...            ...            ...         ...         ...
# 81        1.546826       1.918879       1.715567    0.871874    0.885349
# 469       1.689988       2.059637       1.964124    0.865873    0.888349
# 929       1.844460       2.049933       1.681049    0.865411    0.889051
# 492       1.570213       1.920210       1.835412    0.879177    0.890818
# 523       1.636851       2.320658       1.926914    0.880467    0.910874
#
#       pcc_gt_sparc  pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  \
# 1295      0.675203       0.625269       0.655748      0.450000
# 1306      0.561306       0.314582       0.260038      0.576271
# 1272      0.729478       0.382991       0.485535      0.594595
# 1309      0.556710       0.468892       0.289446      0.520000
# 1298      0.652223       0.463173       0.331338      0.246377
# ...            ...            ...            ...           ...
# 81        0.923937       0.884721       0.914634      0.030864
# 469       0.898442       0.873833       0.893304      0.084615
# 929       0.882345       0.854537       0.901287      0.173333
# 492       0.906901       0.887182       0.905154      0.189781
# 523       0.902270       0.843503       0.901154      0.202128
#
#       enc_dtw_distortion  dec_dtw_distortion  sparc_dtw_distortion
# 1295            1.036364            0.818182              0.020202
# 1306            1.360000            1.360000              0.017241
# 1272            0.135593            0.211864              0.027397
# 1309            1.083333            1.083333              0.061224
# 1298            0.461538            0.576923              0.014706
# ...                  ...                 ...                   ...
# 81              0.235669            0.235669              0.055901
# 469             0.252101            0.285714              0.077519
# 929             0.419355            0.451613              0.094595
# 492             0.423423            0.414414              0.110294
# 523             0.493333            0.493333              0.064516
#
# [1312 rows x 18 columns]

# %%
mngu0_summary[["pcc_gt_dec", "pcc_sparc_dec"]].mean()
# Out:
# pcc_gt_dec       0.778065
# pcc_sparc_dec    0.824394
# dtype: float64

# %%
mngu0_summary["pcc"].mean(), mngu0_summary["pcc"].std()
# Out:
# (np.float64(0.854605064477499), np.float64(0.05692489290881377))

# %%
for col in mngu0_summary.columns:
    if col != "filestem":
        correlation, _ = pearsonr(mngu0_summary["pcc_gt_dec"], mngu0_summary[col])
        print(f"Correlation between pcc_gt_dec and {col}: {correlation:.4f}")
# Out:
# Correlation between pcc_gt_dec and pcc: 0.6334
# Correlation between pcc_gt_dec and duration: 0.3266
# Correlation between pcc_gt_dec and pcc_no_dtw: 0.6334
# Correlation between pcc_gt_dec and dtw_gt_enc: -0.8439
# Correlation between pcc_gt_dec and dtw_gt_dec: -0.8529
# Correlation between pcc_gt_dec and dtw_gt_sparc: -0.6118
# Correlation between pcc_gt_dec and dtw_sparc_enc: -0.3547
# Correlation between pcc_gt_dec and dtw_sparc_dec: -0.3200
# Correlation between pcc_gt_dec and pcc_gt_enc: 0.9324
# Correlation between pcc_gt_dec and pcc_gt_dec: 1.0000
# Correlation between pcc_gt_dec and pcc_gt_sparc: 0.6547
# Correlation between pcc_gt_dec and pcc_sparc_enc: 0.7601
# Correlation between pcc_gt_dec and pcc_sparc_dec: 0.8020
# Correlation between pcc_gt_dec and pred_rel_gap: -0.4632
# Correlation between pcc_gt_dec and enc_dtw_distortion: -0.4773
# Correlation between pcc_gt_dec and dec_dtw_distortion: -0.4734
# Correlation between pcc_gt_dec and sparc_dtw_distortion: -0.0186

# %%
dataset = "MNGU0"
speaker = "s1"
src_data_dir = DATA_DIR / dataset / "src_data" / speaker / "ema_basic_data"
emasrc_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "emasrc"
spk_emb_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "spk_emb"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
reconstructed_dir = DATA_DIR / dataset / "arttts" / speaker / "hifigan_pred"

# %%
from utils_dataset.mngu0 import read_mngu0_ema, MNGU0_features
from utils import plot_art_14

sample_id = worst["filestem"]
arttts_dir = DATA_DIR / dataset / "arttts" / speaker / "arttts_pred" / "v1_1" / "grad_2000"
art_ema = np.load(arttts_dir / f"{sample_id}.npy")
art_ema_14 = art_ema[14:28,:].T
art_ema_align = art_ema[28]
raw_ema_fp = src_data_dir/ f"{sample_id}.ema"
ema_data, nonan = read_mngu0_ema(raw_ema_fp)
sparc_ema = np.load(emasrc_dir / f"{sample_id}.npy")[:,:12]
phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
ema_data_14 = np.pad(ema_data, ((0, 0), (0, 2)), mode='constant', constant_values=0)
ema_data_14 = (ema_data_14 - ema_data_14.mean(axis=0)) / ema_data_14.std(axis=0)
ema_data_14 = ema_data_14[::4,:]
sparc_ema_14 = np.pad(sparc_ema, ((0, 0), (0, 2)), mode='constant', constant_values=0)


fig, _ = plot_art_14([ema_data_14.T,
                      sparc_ema_14.T,
                        art_ema_14.T,
                      ],
                       phnm3=phnm3,
                       figsize=(16, 10),)
fig
# Out:
# /tmp/ipykernel_124714/4157905919.py:14: RuntimeWarning: invalid value encountered in divide
#   ema_data_14 = (ema_data_14 - ema_data_14.mean(axis=0)) / ema_data_14.std(axis=0)

# %%
from utils_dataset.mngu0 import read_mngu0_ema, MNGU0_features
from utils import plot_art_14

raw_ema_fp = list(src_data_dir.glob("*"))[522]
raw_ema_fp = raw_ema_fp.parent / f"mngu0_s1_1215.ema"
sample_id = raw_ema_fp.stem
ema_data, nonan = read_mngu0_ema(raw_ema_fp)
sparc_ema = np.load(emasrc_dir / f"{sample_id}.npy")[:,:12]
phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")

ema_data_14 = np.pad(ema_data, ((0, 0), (0, 2)), mode='constant', constant_values=0)
ema_data_14 = (ema_data_14 - ema_data_14.mean(axis=0)) / ema_data_14.std(axis=0)
ema_data_14 = ema_data_14[::4,:]
sparc_ema_14 = np.pad(sparc_ema, ((0, 0), (0, 2)), mode='constant', constant_values=0)

fig, _ = plot_art_14([ema_data_14.T,
                       sparc_ema_14.T],
                       phnm3=phnm3,
                       figsize=(16, 10),)
fig
# Out:
# /tmp/ipykernel_124714/4041848580.py:12: RuntimeWarning: invalid value encountered in divide
#   ema_data_14 = (ema_data_14 - ema_data_14.mean(axis=0)) / ema_data_14.std(axis=0)

# %% [markdown]
# # Versions comparison

# %%
for k, v in dataset_2_extra_ipa.items():
    print(f"{k} has {len(v)} extra IPA phonemes not present in LJ Speech")
    print()
# Out:
# MSPKA_EMA_ita has 27 extra IPA phonemes not present in LJ Speech
#
# pb2007 has 12 extra IPA phonemes not present in LJ Speech
#
# MNGU0 has 17 extra IPA phonemes not present in LJ Speech
#
# mocha_timit has 9 extra IPA phonemes not present in LJ Speech

# %%
dataset = "MNGU0"
speakers = ["s1"]
versions = ["v1", "v1_1", "v4", "v4_phnmtext", "v5", "v5_preblock"]
truc = create_dataset_summary(dataset, speakers, versions)

for version in versions:
    plt.plot(truc[truc["version"] == version]["epoch"], truc[truc["version"] == version]["pcc_gt_dec"], marker="o", label=version)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("PCC")
plt.title(f"{dataset} PCC GT/Dec scores over epochs")
plt.grid()
# v4_phnmtext far from being the best, lot of out of vocab phonemes in MNGU0
# but v4_phnmtext performs better than v4, probably because v4 use letter embeddings as well
# which can be more ambiguous than phonemes on in vocabulary cases.

# %%
dataset = "mocha_timit"
speakers = ["faet0", "fsew0", "ffes0", "maps0", "msak0", "mjjn0"]
versions = ["v1", "v1_1", "v4", "v4_phnmtext", "v5", "v5_preblock"]
truc = create_dataset_summary(dataset, speakers, versions)
truc = truc.groupby(["version", "epoch"]).mean("pcc_gt_dec").reset_index()

for version in versions:
    plt.plot(truc[truc["version"] == version]["epoch"], truc[truc["version"] == version]["pcc_gt_dec"], marker="o", label=version)
    
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("PCC")
plt.title(f"{dataset} PCC GT/Dec scores over epochs")
plt.grid()
# v4_phnmtext better, indeed mocha has fewer out of vocabulary phonemes compared to mngu0 (6 vs 17)
# v4 performs better as well, here the generalization advantage of the other versions is useless
# since the phnm vocabularies overlap a lot. The learnt embeeddings of v4s allow more powerful representations

# %%
dataset = "MSPKA_EMA_ita"
speakers = ["cnz", "olm"]
versions = ["v1", "v1_1", "v4", "v4_phnmtext", "v5", "v5_preblock"]
truc = create_dataset_summary(dataset, speakers, versions)
truc = truc.groupby(["version", "epoch"]).mean("pcc_gt_dec").reset_index()

for version in versions:
    plt.plot(truc[truc["version"] == version]["epoch"], truc[truc["version"] == version]["pcc_gt_dec"], marker="o", label=version)
    
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("PCC")
plt.title(f"{dataset} PCC GT/Dec scores over epochs")
plt.grid()
# v4_phnmtext performs very poorly, expected since mspka has a lot of out of vocabulary phnms (italian)
# v4 performs poorly as well compared to the other versions because the latter use phnm ternary features
# and are expected to perform better generalization on unseen phonemes
# However v4 performs better than v4_phnmtext, because v4 use letter embeddings as well and some letters are cross-lingual

# %%
truc
# Out:
#         version  epoch  pcc_no_dtw  dtw_gt_enc  dtw_gt_dec  dtw_gt_sparc  \
# 0            v1    200    0.762753    2.544092    2.492535      2.069043
# 1            v1   1000    0.762753    2.562462    2.482087      2.069043
# 2            v1   2000    0.762753    2.552356    2.470332      2.069043
# 3            v1   3000    0.762753    2.541851    2.469894      2.069043
# 4            v1   4000    0.762753    2.549480    2.469172      2.069043
# 5            v1   5000    0.762753    2.555914    2.473889      2.069043
# 6          v1_1    200    0.762753    2.515020    2.476150      2.069043
# 7          v1_1   1000    0.762753    2.542601    2.493399      2.069043
# 8          v1_1   2000    0.762753    2.540997    2.463519      2.069043
# 9          v1_1   3000    0.762753    2.540439    2.463285      2.069043
# 10         v1_1   4000    0.762753    2.544521    2.466034      2.069043
# 11         v1_1   5000    0.762753    2.534613    2.464501      2.069043
# 12           v4    200    0.762753    2.643849    2.619373      2.069043
# 13           v4   1000    0.762753    2.640097    2.599720      2.069043
# 14           v4   2000    0.762753    2.636182    2.587475      2.069043
# 15           v4   3000    0.762753    2.632549    2.588213      2.069043
# 16           v4   4000    0.762753    2.631559    2.587042      2.069043
# 17           v4   5000    0.762753    2.635359    2.587835      2.069043
# 18  v4_phnmtext   1000    0.762753    2.802491    2.748789      2.069043
# 19  v4_phnmtext   2000    0.762753    2.802194    2.740425      2.069043
# 20           v5   1000    0.762753    2.525755    2.480234      2.069043
# 21           v5   2000    0.762753    2.551085    2.474722      2.069043
# 22           v5   3000    0.762753    2.541285    2.470677      2.069043
# 23  v5_preblock   1000    0.762753    2.627241    2.511328      2.069043
# 24  v5_preblock   2000    0.762653    2.617281    2.506493      2.069549
# 25  v5_preblock   3000    0.762719    2.623208    2.503538      2.068959
# 26  v5_preblock   4000    0.762747    2.615378    2.497164      2.069128
# 27  v5_preblock   5000    0.762656    2.606500    2.501137      2.069235
#
#     dtw_sparc_enc  dtw_sparc_dec  pcc_gt_enc  pcc_gt_dec  pcc_gt_sparc  \
# 0        1.716595       1.683927    0.648081    0.661443      0.793625
# 1        1.743800       1.674972    0.638958    0.661372      0.793625
# 2        1.733714       1.662610    0.639615    0.662160      0.793625
# 3        1.730723       1.666158    0.643337    0.662938      0.793625
# 4        1.745247       1.671678    0.639891    0.662015      0.793625
# 5        1.750432       1.675081    0.638905    0.660915      0.793625
# 6        1.695657       1.674426    0.654800    0.664182      0.793625
# 7        1.736688       1.685692    0.643458    0.655690      0.793625
# 8        1.730211       1.667622    0.643924    0.666185      0.793625
# 9        1.734178       1.667368    0.644224    0.665680      0.793625
# 10       1.738990       1.670171    0.642098    0.664703      0.793625
# 11       1.735216       1.668156    0.645125    0.664826      0.793625
# 12       1.858684       1.846183    0.594666    0.600758      0.793625
# 13       1.860554       1.832319    0.595682    0.607222      0.793625
# 14       1.860089       1.827146    0.597169    0.611294      0.793625
# 15       1.858219       1.825469    0.599628    0.612734      0.793625
# 16       1.862084       1.826528    0.599222    0.612227      0.793625
# 17       1.860920       1.827092    0.597324    0.612655      0.793625
# 18       2.038530       1.996702    0.533861    0.552919      0.793625
# 19       2.037729       1.988657    0.534200    0.555325      0.793625
# 20       1.724043       1.679839    0.649991    0.660735      0.793625
# 21       1.750401       1.679957    0.640688    0.661408      0.793625
# 22       1.746134       1.679981    0.642399    0.661916      0.793625
# 23       1.790816       1.684094    0.620062    0.654110      0.793625
# 24       1.787690       1.691445    0.622222    0.654291      0.793525
# 25       1.789896       1.690335    0.621090    0.655789      0.793622
# 26       1.780541       1.677944    0.623232    0.657769      0.793584
# 27       1.776584       1.692260    0.623010    0.652525      0.793561
#
#     pcc_sparc_enc  pcc_sparc_dec  pred_rel_gap  enc_dtw_distortion  \
# 0        0.749173       0.754438      0.129022            0.316271
# 1        0.741007       0.756625      0.136754            0.290772
# 2        0.742970       0.759196      0.146635            0.278810
# 3        0.744328       0.758410      0.145608            0.280992
# 4        0.740034       0.756241      0.147696            0.282179
# 5        0.739008       0.755744      0.150888            0.284510
# 6        0.754468       0.756722      0.134651            0.296184
# 7        0.742430       0.752239      0.141905            0.292717
# 8        0.744998       0.759183      0.143567            0.285882
# 9        0.743872       0.758910      0.142966            0.286822
# 10       0.743142       0.758842      0.148539            0.279469
# 11       0.743530       0.758634      0.148272            0.278846
# 12       0.687282       0.688866      0.148442            0.292088
# 13       0.686170       0.693396      0.153775            0.289421
# 14       0.687228       0.695671      0.155910            0.288614
# 15       0.687560       0.696586      0.151224            0.294389
# 16       0.686624       0.696130      0.157069            0.290890
# 17       0.686029       0.696304      0.156779            0.289632
# 18       0.610896       0.629444      0.129525            0.371610
# 19       0.611717       0.632248      0.131094            0.374188
# 20       0.747572       0.754758      0.140336            0.293917
# 21       0.739020       0.754055      0.145270            0.290203
# 22       0.740228       0.754502      0.153130            0.278598
# 23       0.728242       0.754903      0.136159            0.295897
# 24       0.729616       0.752944      0.139788            0.287139
# 25       0.728520       0.753310      0.137528            0.289085
# 26       0.731111       0.756338      0.138364            0.291533
# 27       0.732243       0.751685      0.155155            0.269534
#
#     dec_dtw_distortion  sparc_dtw_distortion
# 0             0.333794              0.098857
# 1             0.311790              0.098857
# 2             0.300072              0.098857
# 3             0.300661              0.098857
# 4             0.302898              0.098857
# 5             0.305413              0.098857
# 6             0.315482              0.098857
# 7             0.311453              0.098857
# 8             0.305137              0.098857
# 9             0.306038              0.098857
# 10            0.299148              0.098857
# 11            0.298187              0.098857
# 12            0.305380              0.098857
# 13            0.304908              0.098857
# 14            0.305309              0.098857
# 15            0.309176              0.098857
# 16            0.306048              0.098857
# 17            0.304000              0.098857
# 18            0.385264              0.098857
# 19            0.389905              0.098857
# 20            0.311001              0.098857
# 21            0.308875              0.098857
# 22            0.296375              0.098857
# 23            0.319878              0.098857
# 24            0.313171              0.098707
# 25            0.315842              0.098967
# 26            0.315390              0.098903
# 27            0.296280              0.098927

# %%
datasets = ["mocha_timit", "MNGU0", "MSPKA_EMA_ita"]
dataset_2_speakers = {
        "MSPKA_EMA_ita": ["cnz", "olm"],
        "pb2007": ["spk1"],
        "mocha_timit": ["faet0", "ffes0", "fsew0", "maps0", "mjjn0", "msak0"],
        "MNGU0": ["s1"],
    }
ckpt_name = "grad_2000"

data = []
for i in range(len(datasets)):
    dataset = datasets[i]
    for version in ["v1", "v1_1", "v4", "v4_phnmtext"]:
        version_df = pd.concat([get_specific_summary(dataset, speaker, version, ckpt_name) for speaker in dataset_2_speakers[dataset]])
        row = {
            "dataset": dataset,
            "version": version,
            "ckpt_name": ckpt_name,
            "pcc_gt_dec_mean": version_df["pcc_gt_dec"].mean(),
            "pcc_gt_dec_std": version_df["pcc_gt_dec"].std(),
        }
        data.append(row)
data = pd.DataFrame(data)

# %%
datasets = ["MSPKA_EMA_ita", "mocha_timit", "MNGU0"]
versions = ["v1", "v1_1"]#, "v4", "v4_phnmtext"]
width = 0.2  # Bar width
x = np.arange(len(datasets))  # Dataset positions
n_epochs = 3000

# Prepare data for plotting
mean_scores = []
std_scores = []

for version in versions:
    means = []
    stds = []
    for dataset in datasets:
        version_df = pd.concat([get_specific_summary(dataset, speaker, version, f"grad_{n_epochs}") for speaker in dataset_2_speakers[dataset]])
        means.append(version_df["pcc_gt_dec"].mean())
        stds.append(version_df["pcc_gt_dec"].std())
    mean_scores.append(means)
    std_scores.append(stds)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

for i, version in enumerate(versions):
    ax.bar(x + i * width, mean_scores[i], width, yerr=std_scores[i], label=version, capsize=5)

# Add labels and legend
ax.set_xlabel("Datasets")
ax.set_ylabel("Mean PCC GT Dec")
ax.set_title(f"Mean PCC GT Dec and Std for Each Version Across Datasets after {n_epochs} epochs")
ax.set_xticks(x + width)
ax.set_xticklabels(datasets)
ax.legend()
ax.grid(axis="y")

plt.tight_layout()
plt.show()

# %%
datasets = ["MSPKA_EMA_ita", "mocha_timit", "MNGU0"]
version = "v1_1"
cols = ["pcc_gt_dec", "pcc_sparc_dec"]
width = 0.2  # Bar width
x = np.arange(len(datasets))  # Dataset positions

# Prepare data for plotting
mean_scores = {k : [] for k in cols}
std_scores = {k}
means = []
stds = []
for dataset in datasets:
    version_df = pd.concat([get_specific_summary(dataset, speaker, version, "grad_2000") for speaker in dataset_2_speakers[dataset]])
    for col in cols:
        means.append(version_df[col].mean())
        stds.append(version_df[col].std())
mean_scores.append(means)
std_scores.append(stds)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

for i, col in enumerate(cols):
    ax.bar(x + i * width, mean_scores[i], width, yerr=std_scores[i], label=version, capsize=5)

# Add labels and legend
ax.set_xlabel("Datasets")
ax.set_ylabel("Mean PCC GT Dec")
ax.set_title("Mean PCC GT Dec and Std for Each Version Across Datasets after 2000 epochs")
ax.set_xticks(x + width)
ax.set_xticklabels(datasets)
ax.legend()
ax.grid(axis="y")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 17
#      15         means.append(version_df[col].mean())
#      16         stds.append(version_df[col].std())
# ---> 17 mean_scores.append(means)
#      18 std_scores.append(stds)
#      20 # Plotting
#
# AttributeError: 'dict' object has no attribute 'append'

# %% [markdown]
# # Phoneme level analysis

# %%
from text.phnms import get_phnms_from_phnm3
from text.converters import arpabet2ipa

lj_ipa_set = set(arpabet2ipa.values())

version = "v1_1"
ckpt_name = "grad_3000"

# %% [markdown]
# ## MSPKA_EMA_ita

# %%
from utils_dataset.mspka import mspka2ipa

mspka_ipa_set = set(mspka2ipa.values())
extra_ipa_set = mspka_ipa_set - lj_ipa_set

dataset = "MSPKA_EMA_ita"
speakers = ["cnz", "olm", "lls"]

# %%
phnms_stats = {}

speaker = "cnz"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
cnz_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in cnz_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "lls"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
lls_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in lls_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "olm"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
olm_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in olm_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

phnms_scores = {phnm: (count, np.mean(values), np.std(values)) for phnm, (count, values) in phnms_stats.items() if count > 10}

# %%
# Separate phonemes into two groups based on their presence in extra_ipa_set
extra_phnms = [phnm for phnm in phnms_scores.keys() if phnm in extra_ipa_set]
regular_phnms = [phnm for phnm in phnms_scores.keys() if phnm not in extra_ipa_set]

# Extract scores for each group
extra_scores = [phnms_scores[phnm][1] for phnm in extra_phnms]
extra_stds = [phnms_scores[phnm][2] for phnm in extra_phnms]
regular_scores = [phnms_scores[phnm][1] for phnm in regular_phnms]
regular_stds = [phnms_scores[phnm][2] for phnm in regular_phnms]

# Plot the phonemes with different colors
plt.figure(figsize=(12, 6))
plt.plot(extra_phnms, extra_scores, marker='o', color='red', label='Extra IPA Set')
plt.plot(regular_phnms, regular_scores, marker='o', color='blue', label='Regular IPA Set')
#plot stds
plt.fill_between(extra_phnms, np.array(extra_scores) - np.array(extra_stds),
                    np.array(extra_scores) + np.array(extra_stds), color='red', alpha=0.2)
plt.fill_between(regular_phnms, np.array(regular_scores) - np.array(regular_stds),
                    np.array(regular_scores) + np.array(regular_stds), color='blue', alpha=0.2)

# Add legend and labels
plt.legend()
plt.xlabel("Phonemes")
plt.ylabel("Scores")
plt.title("Phoneme Scores Colored by IPA Set")
plt.grid()
plt.show()

# %% [markdown]
# ## pb2007

# %%
from utils_dataset.pb2007 import pb20072ipa

pb2007_ipa_set = set(pb20072ipa.values())
extra_ipa_set = pb2007_ipa_set - lj_ipa_set

dataset = "pb2007"
speakers = ["spk1"]

# %%
phnms_stats = {}

speaker = "spk1"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
spk1_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in spk1_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])
        
phnms_scores = {phnm: (count, np.mean(values), np.std(values)) for phnm, (count, values) in phnms_stats.items() if count > 10}

# %%
# Separate phonemes into two groups based on their presence in extra_ipa_set
extra_phnms = [phnm for phnm in phnms_scores.keys() if phnm in extra_ipa_set]
regular_phnms = [phnm for phnm in phnms_scores.keys() if phnm not in extra_ipa_set]

# Extract scores for each group
extra_scores = [phnms_scores[phnm][1] for phnm in extra_phnms]
extra_stds = [phnms_scores[phnm][2] for phnm in extra_phnms]
regular_scores = [phnms_scores[phnm][1] for phnm in regular_phnms]
regular_stds = [phnms_scores[phnm][2] for phnm in regular_phnms]

# Plot the phonemes with different colors
plt.figure(figsize=(12, 6))
plt.plot(extra_phnms, extra_scores, marker='o', color='red', label='Extra IPA Set')
plt.plot(regular_phnms, regular_scores, marker='o', color='blue', label='Regular IPA Set')
#plot stds
plt.fill_between(extra_phnms, np.array(extra_scores) - np.array(extra_stds),
                    np.array(extra_scores) + np.array(extra_stds), color='red', alpha=0.2)
plt.fill_between(regular_phnms, np.array(regular_scores) - np.array(regular_stds),
                    np.array(regular_scores) + np.array(regular_stds), color='blue', alpha=0.2)

# Add legend and labels
plt.legend()
plt.xlabel("Phonemes")
plt.ylabel("Scores")
plt.title("Phoneme Scores Colored by IPA Set")
plt.grid()
plt.show()

# %% [markdown]
# ## MNGU0

# %%
from utils_dataset.mngu0 import mngu02ipa

mngu0_ipa_set = set(mngu02ipa.values())
extra_ipa_set = mngu0_ipa_set - lj_ipa_set

dataset = "MNGU0"
speakers = ["spk1"]

# %%
phnms_stats = {}

speaker = "s1"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
s1_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in s1_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])
        
phnms_scores = {phnm: (count, np.mean(values), np.std(values)) for phnm, (count, values) in phnms_stats.items() if count > 10}

# %%
# Separate phonemes into two groups based on their presence in extra_ipa_set
extra_phnms = [phnm for phnm in phnms_scores.keys() if phnm in extra_ipa_set]
regular_phnms = [phnm for phnm in phnms_scores.keys() if phnm not in extra_ipa_set]

# Extract scores for each group
extra_scores = [phnms_scores[phnm][1] for phnm in extra_phnms]
extra_stds = [phnms_scores[phnm][2] for phnm in extra_phnms]
regular_scores = [phnms_scores[phnm][1] for phnm in regular_phnms]
regular_stds = [phnms_scores[phnm][2] for phnm in regular_phnms]

# Plot the phonemes with different colors
plt.figure(figsize=(12, 6))
plt.plot(extra_phnms, extra_scores, marker='o', color='red', label='Extra IPA Set')
plt.plot(regular_phnms, regular_scores, marker='o', color='blue', label='Regular IPA Set')
#plot stds
plt.fill_between(extra_phnms, np.array(extra_scores) - np.array(extra_stds),
                    np.array(extra_scores) + np.array(extra_stds), color='red', alpha=0.2)
plt.fill_between(regular_phnms, np.array(regular_scores) - np.array(regular_stds),
                    np.array(regular_scores) + np.array(regular_stds), color='blue', alpha=0.2)

# Add legend and labels
plt.legend()
plt.xlabel("Phonemes")
plt.ylabel("Scores")
plt.title("Phoneme Scores Colored by IPA Set")
plt.grid()
plt.show()

# %% [markdown]
# ## mocha_timit

# %%
dataset = "mocha_timit"
speakers = ["fsew0", "faet0", "ffes0", "maps0", "mjjn0", "msak0"]

# %%
phnms_stats = {}

speaker = "fsew0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
fsew0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in fsew0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "faet0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
faet0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in faet0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "ffes0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
ffes0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in ffes0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "maps0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
maps0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in maps0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "mjjn0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
mjjn0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in mjjn0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])

speaker = "msak0"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
phnm3_dir = DATA_DIR / dataset / "arttts" / speaker / "phnm3"
msak0_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

for i, row in msak0_df.iterrows():
    sample_id = row["filestem"]
    phnm3 = np.load(phnm3_dir / f"{sample_id}_phnm3.npy")
    #phnms = get_phnms_from_phnm3(phnm3, merge_diphtongues=False)
    for start, end, phnm in phnm3:
        if phnm not in phnms_stats:
            phnms_stats[phnm] = [0, []]  # [count, score]
        phnms_stats[phnm][0] += 1
        phnms_stats[phnm][1].append(row["pcc_gt_dec"])
        
phnms_scores = {phnm: (count, np.mean(values), np.std(values)) for phnm, (count, values) in phnms_stats.items() if count > 10}

# %%
mocha_ipa_set = set(phnms_scores.keys())
extra_ipa_set = mocha_ipa_set - lj_ipa_set

# Separate phonemes into two groups based on their presence in extra_ipa_set
extra_phnms = [phnm for phnm in phnms_scores.keys() if phnm in extra_ipa_set]
regular_phnms = [phnm for phnm in phnms_scores.keys() if phnm not in extra_ipa_set]

# Extract scores for each group
extra_scores = [phnms_scores[phnm][1] for phnm in extra_phnms]
extra_stds = [phnms_scores[phnm][2] for phnm in extra_phnms]
regular_scores = [phnms_scores[phnm][1] for phnm in regular_phnms]
regular_stds = [phnms_scores[phnm][2] for phnm in regular_phnms]

# Plot the phonemes with different colors
plt.figure(figsize=(12, 6))
plt.plot(extra_phnms, extra_scores, marker='o', color='red', label='Extra IPA Set')
plt.plot(regular_phnms, regular_scores, marker='o', color='blue', label='Regular IPA Set')
#plot stds
plt.fill_between(extra_phnms, np.array(extra_scores) - np.array(extra_stds),
                    np.array(extra_scores) + np.array(extra_stds), color='red', alpha=0.2)
plt.fill_between(regular_phnms, np.array(regular_scores) - np.array(regular_stds),
                    np.array(regular_scores) + np.array(regular_stds), color='blue', alpha=0.2)

# Add legend and labels
plt.legend()
plt.xlabel("Phonemes")
plt.ylabel("Scores")
plt.title("Phoneme Scores Colored by IPA Set")
plt.grid()
plt.show()

# %% [markdown]
# # Pitch sensitivity

# %% [markdown]
# # Spk_emb sensitivity

# %% [markdown]
# ## build mean spk_embs

# %%
dataset = "MNGU0"
speaker = "s1"
analysis_dir = DATA_DIR / dataset / "arttts" / speaker / "analysis"
s1_df = pd.read_csv(analysis_dir / f"quanti_art_comp_{version}_{ckpt_name}.csv")

spk_emb_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "spk_emb"

fp_list = list(spk_emb_dir.glob("*.npy"))
spk_embs = np.zeros((len(fp_list), 64), dtype=np.float32)
for i, fp in enumerate(fp_list):
    sample_id = fp.stem
    spk_emb = np.load(fp)
    spk_embs[i, :] = spk_emb
np.save(spk_emb_dir / "mean_spk_emb.npy", spk_embs.mean(axis=0))

# %%
spk_embs.mean(axis=0), spk_embs.std(axis=0)
plt.plot(spk_embs.mean(axis=0), label="mean")
plt.fill_between(np.arange(64), spk_embs.mean(axis=0) - spk_embs.std(axis=0),
                 spk_embs.mean(axis=0) + spk_embs.std(axis=0), alpha=0.5, label="std")
plt.title(f"{dataset} {speaker} Speaker Embeddings")
plt.xlabel("Embedding Dimension")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
dataset = "mocha_timit"
speakers = ['fsew0', 'faet0', 'maps0', 'msak0', 'mjjn0', 'ffes0']
speaker = speakers[5]
for speaker in speakers:
    spk_emb_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "spk_emb"

    fp_list = list(spk_emb_dir.glob("*.npy"))
    spk_embs = np.zeros((len(fp_list), 64), dtype=np.float32)
    for i, fp in enumerate(fp_list):
        sample_id = fp.stem
        spk_emb = np.load(fp)
        spk_embs[i, :] = spk_emb
    np.save(spk_emb_dir / "mean_spk_emb.npy", spk_embs.mean(axis=0))

plt.plot(spk_embs.mean(axis=0), label="mean")
plt.fill_between(np.arange(64), spk_embs.mean(axis=0) - spk_embs.std(axis=0),
                 spk_embs.mean(axis=0) + spk_embs.std(axis=0), alpha=0.5, label="std")
plt.title(f"{dataset} {speaker} Speaker Embeddings")
plt.xlabel("Embedding Dimension")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
spk1_sentences_df = spk1_df[spk1_df["sentence_types"] == "sentence"]

dataset = "pb2007"
speaker = "spk1"
spk_emb_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "spk_emb"

fp_list = list(spk_emb_dir.glob("*.npy"))
#only use sentences spk_emb
fp_list = [spk_emb_dir / f"{filestem}.npy" for filestem in spk1_sentences_df["filestem"]]
spk_embs = np.zeros((len(fp_list), 64), dtype=np.float32)
for i, fp in enumerate(fp_list):
    sample_id = fp.stem
    spk_emb = np.load(fp)
    spk_embs[i, :] = spk_emb
np.save(spk_emb_dir / "mean_spk_emb.npy", spk_embs.mean(axis=0))

plt.plot(spk_embs.mean(axis=0), label="mean")
plt.fill_between(np.arange(64), spk_embs.mean(axis=0) - spk_embs.std(axis=0),
                 spk_embs.mean(axis=0) + spk_embs.std(axis=0), alpha=0.5, label="std")
plt.title(f"{dataset} {speaker} Speaker Embeddings")
plt.xlabel("Embedding Dimension")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
dataset = "MSPKA_EMA_ita"
speakers = ['cnz', 'lls', 'olm']

for speaker in speakers:
    spk_emb_dir = DATA_DIR / dataset / "arttts" / speaker / "encoded_audio_en" / "spk_emb"

    fp_list = list(spk_emb_dir.glob("*.npy"))
    spk_embs = np.zeros((len(fp_list), 64), dtype=np.float32)
    for i, fp in enumerate(fp_list):
        sample_id = fp.stem
        spk_emb = np.load(fp)
        spk_embs[i, :] = spk_emb
    np.save(spk_emb_dir / "mean_spk_emb.npy", spk_embs.mean(axis=0))

plt.plot(spk_embs.mean(axis=0), label="mean")
plt.fill_between(np.arange(64), spk_embs.mean(axis=0) - spk_embs.std(axis=0),
                 spk_embs.mean(axis=0) + spk_embs.std(axis=0), alpha=0.5, label="std")
plt.title(f"{dataset} {speaker} Speaker Embeddings")
plt.xlabel("Embedding Dimension")
plt.ylabel("Value")
plt.legend()
plt.show()

# %% [markdown]
# # Check text embedding (irregular results on italian) shouldn'it be able since not trained on italian words and only trained on english phonemes from cmudict in theory

# %%
dataset = "MSPKA_EMA_ita"
speaker = "lls"

dataset_2_spkmetadata = {
        "MSPKA_EMA_ita": "mixed_speaker_metadata_100Hz.joblib",
        "pb2007": "1.0_speaker_metadata_100Hz.joblib",
        "mocha_timit": "mixed_speaker_metadata_100Hz.joblib",
    }

processed_data_dir = DATA_DIR / dataset / "processed_data"
spkmetadata_filename = dataset_2_spkmetadata[dataset]

spkmeta = joblib.load(processed_data_dir / f"{speaker}/{spkmetadata_filename}")
ids = spkmeta.list_valid_ids()
pcc_scores = []
filestems = []
splits = []
durations = []
sentences = []
for id in ids:
    sentencemeta = spkmeta.sentence_info[id]
    filestems.append(sentencemeta.filestem)
    splits.append(sentencemeta.split)
    pcc_scores.append(sentencemeta.PCC_score)
    durations.append(sentencemeta.duration)
    sentences.append(sentencemeta.sentence)

# %%
from data_textart import TextArtDataset
from configs import params_v4

valid_dataset = TextArtDataset(
        params_v4.valid_filelist_path,
        cmudict_path=params_v4.cmudict_path,
        add_blank=params_v4.add_blank,
        data_root_dir=params_v4.data_root_dir,
        reorder_feats=params_v4.reorder_feats,
        pitch_idx=params_v4.pitch_idx,
        log_normalize_loudness=params_v4.log_normalize_loudness,
        loudness_idx=params_v4.loudness_idx,
        load_coder=False,
        sparc_ckpt_path=params_v4.sparc_ckpt_path,
    )

# %%
from text import symbols

symbols_ = symbols + [" "]
s = valid_dataset.get_text(sentences[297])
print(sentences[297])
print([symbols_[e] for e in s])
# Out:
# è il capitano giallorosso che scatta in posizione leggermente irregolare ma non ravvisata dall'assistente
# [' ', '@IY1', ' ', ' ', ' ', '@IH1', ' ', '@L', ' ', ' ', ' ', '@K', ' ', '@AA0', ' ', '@P', ' ', '@IY0', ' ', '@T', ' ', '@AA1', ' ', '@N', ' ', '@OW0', ' ', ' ', ' ', 'g', ' ', 'i', ' ', 'a', ' ', 'l', ' ', 'l', ' ', 'o', ' ', 'r', ' ', 'o', ' ', 's', ' ', 's', ' ', 'o', ' ', ' ', ' ', '@CH', ' ', '@EY1', ' ', ' ', ' ', 's', ' ', 'c', ' ', 'a', ' ', 't', ' ', 't', ' ', 'a', ' ', ' ', ' ', '@IH0', ' ', '@N', ' ', ' ', ' ', 'p', ' ', 'o', ' ', 's', ' ', 'i', ' ', 'z', ' ', 'i', ' ', 'o', ' ', 'n', ' ', 'e', ' ', ' ', ' ', 'l', ' ', 'e', ' ', 'g', ' ', 'g', ' ', 'e', ' ', 'r', ' ', 'm', ' ', 'e', ' ', 'n', ' ', 't', ' ', 'e', ' ', ' ', ' ', 'i', ' ', 'r', ' ', 'r', ' ', 'e', ' ', 'g', ' ', 'o', ' ', 'l', ' ', 'a', ' ', 'r', ' ', 'e', ' ', ' ', ' ', '@M', ' ', '@AA1', ' ', ' ', ' ', '@N', ' ', '@AA1', ' ', '@N', ' ', ' ', ' ', 'r', ' ', 'a', ' ', 'v', ' ', 'v', ' ', 'i', ' ', 's', ' ', 'a', ' ', 't', ' ', 'a', ' ', ' ', ' ', 'd', ' ', 'a', ' ', 'l', ' ', 'l', ' ', "'", ' ', 'a', ' ', 's', ' ', 's', ' ', 'i', ' ', 's', ' ', 't', ' ', 'e', ' ', 'n', ' ', 't', ' ', 'e', ' ']

# %%
for i, s in enumerate(sentences):
    if "capitano" in s:
        print(s)
        print(i)
# Out:
# Poco dopo una grossa opportunità per il capitano giallorosso
# 296
# è il capitano giallorosso che scatta in posizione leggermente irregolare ma non ravvisata dall'assistente
# 297

# %%
train_dataset = TextArtDataset(
    params_v4.train_filelist_path,
    cmudict_path=params_v4.cmudict_path,
    add_blank=params_v4.add_blank,
    data_root_dir=DATA_DIR,
    reorder_feats=params_v4.reorder_feats,
    pitch_idx=params_v4.pitch_idx,
    log_normalize_loudness=params_v4.log_normalize_loudness,
    loudness_idx=params_v4.loudness_idx,
    load_coder=False,
    sparc_ckpt_path=params_v4.sparc_ckpt_path,
)

# %%
train_dataset.filepaths_list
# Out:
# [['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0146.npy',
#   'from the building he was on to a distant wall, with a drop of sixty feet between.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0095.npy',
#   'She said that if she ever spoke to her husband the way Marina Oswald spoke to her husband, quote, we would not last long, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ046-0132.npy',
#   'in nineteen sixty-three the total exceeded thirty-two thousand items.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0012.npy',
#   'At about this time he heard the first shot.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0197.npy',
#   "of the Lamb's Coffee House;"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ009-0118.npy',
#   'could hardly witness this ceremony without being affected. The men, who were so lately snatched from the jaws of death,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0155.npy',
#   'Both concluded that the prints were the right palm and left index finger of Lee Oswald. No other identifiable prints were found on the bag.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0172.npy',
#   'I never said anything to him again and he never said anything to me again, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ047-0094.npy',
#   'by anti-Castro Cubans while distributing leaflets on behalf of the Fair Play for Cuba Committee.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0215.npy',
#   'Frazier added that the scope would cause a slight miss to the right.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ020-0062.npy',
#   'Graham Rolls are made by treating the dough mixed for Graham bread as above and following the foregoing receipt in every section, but allowing more time for rising and baking.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ017-0284.npy',
#   'was too much for his nerves, and he so nearly fainted that he had to be seated in a chair.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ027-0130.npy',
#   'these evidences have been in the past thirty years somewhat overshadowed by the far more surprising evidences'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ009-0101.npy',
#   'move with a quick, jerking motion, not naturally, but, as it were, like the affected parts of a galvanized corpse.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ005-0224.npy',
#   'but nothing had been done to improve the prison buildings.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0089.npy',
#   'Against the background of the critical events of November twenty-two, however,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ005-0139.npy',
#   'making an average of nineteen persons occupying each room.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0019.npy',
#   'to make a great archway, and to make the character of it more imposing than if it had been situated in the country, and had been an ordinary prison.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0002.npy',
#   'The old notion always prevailed that Newgate was impregnable, so to speak, from within,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0246.npy',
#   'Each of the agents who visited the Press Club or the Cellar Coffee House (apart from the three members of the midnight shift)'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0023.npy',
#   'Measures remedial, although at best partial and incomplete, were introduced from time to time.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ025-0089.npy',
#   'The third distinction is based on a completely erroneous conception of the chemical differences'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0088.npy',
#   'Examination of these procedures shows that in most respects they were well conceived and ably executed by the personnel of the Service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0197.npy',
#   'He drove a police car painted distinctive colors with Number ten prominently displayed on each side.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0242.npy',
#   "entered the stream, which had now sunk so as to reach about midway up a man's thigh, and thus got into the town."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0145.npy',
#   'In general, our family life began to deteriorate after we arrived in America.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0337.npy',
#   'Were a metropolitan prison erected on the same lines, with all the space not only for air and exercise, but for day rooms and sleeping cells'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ044-0058.npy',
#   'that an anti-Castro organization had maintained offices there for a period ending early in nineteen sixty-two.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0137.npy',
#   'He was then shown two photographs of Oswald and he advised that Oswald was, quote, unquestionably, end quote, the man he saw.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0162.npy',
#   'Other changes affecting the condition and proper treatment of prisoners were not made until the inspector had urged and recommended them.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0210.npy',
#   'Frazier testified that while he could not tell when the defect occurred, but that a person familiar with the weapon could compensate for it.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0269.npy',
#   'He was known to the whole criminal fraternity as a high-class receiver of stolen goods, a negotiator more especially of stolen paper,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0197.npy',
#   'On November fifteen, nineteen sixty-three, the same day that his wife told him not to come to Irving, Oswald could have assumed'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0177.npy',
#   'and Robert I. Bouck, who was in charge of the Protective Research Section of the Secret Service, believed that the accumulation of the facts known to the FBI'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0015.npy',
#   'His hair, though gray, was thick, and lay smooth over his forehead.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0006.npy',
#   'or to the Vice President, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0177.npy',
#   'that such a procedure would not be consistent with the nature and purpose of the motorcade to let the people see their President and to welcome him to their city.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0177.npy',
#   'A scheme for heating the whole prison with hot-water pipes, after the system now generally adopted elsewhere, was considered,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0027.npy',
#   'The internal arrangements of the new model were carefully supervised by a body of distinguished men, among which were many peers, Lord John Russell,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0277.npy',
#   'He felt that each agent recognized the seriousness of the infraction and that there was no danger of a repetition.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0113.npy',
#   'The bag found on the sixth floor was eighty-eight inches long.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0062.npy',
#   'then joined in the effort to revive the President.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0131.npy',
#   'a person squatting or kneeling exposes more of his body than would normally be the case.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0134.npy',
#   "The County Court was the sheriff's, who sat there surrounded by the bishop and the magnates of the county;"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0126.npy',
#   'that the exceptional instances of wrong-doing in government are probably less numerous than in almost every other line of endeavor.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0116.npy',
#   'looking out toward the crowd, and Special Agent Kellerman assumed his position next to the car.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0116.npy',
#   'The number of processes against debtors annually was extraordinary.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0129.npy',
#   'firing it, with ten rounds.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0086.npy',
#   'the lips are thin, the chin prominent; the neck is that of a strong vigorous man.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ024-0062.npy',
#   'President Taft appointed five members and named a Chief Justice;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0273.npy',
#   "The Commission has, however, from its examination of the facts of President Kennedy's assassination"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ017-0149.npy',
#   'He had met her at a boarding-house, where he lived with his own wife, a person of "shady" antecedents,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0115.npy',
#   "Oswald's use of the stairway is consistent with the testimony of other employees in the building."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0191.npy',
#   'Oswald engaged in such practice. If the assassin missed either the first or third shot,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0051.npy',
#   'In spite of the fact that unemployment remains a serious problem'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0106.npy',
#   "His palace in Babylon was one of the world's largest buildings, but the walls with which he protected his palace and city were the wonder of the whole world."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0209.npy',
#   'X-rays and photographs were taken preliminarily and the pathological examination began at about eight p.m.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ017-0135.npy',
#   'Dove, a fiendish brute, found from the evidence in that case that he could kill his wife, whom he hated,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0130.npy',
#   'two hundred eighty-five thousand, nine hundred fifty pounds; in other words, that to recover eighty odd thousand pounds,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ044-0198.npy',
#   'as he experienced successive failures in his jobs, in his political activity, and in his personal relationships.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ020-0009.npy',
#   'Three cups of lukewarm water in which the potatoes were boiled, strained through a coarse cloth.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0195.npy',
#   'and yet this doctrine requires the utmost, utmost restraint, a state of being in itself majestic in power, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ029-0079.npy',
#   'was a one-story building with few entrances and easy to make secure, but it lacked necessary food-handling facilities'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0088.npy',
#   'There was no general rule of employment. Hard labor was often not insisted upon in separate confinement;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0256.npy',
#   'During the reigns of the two following Persian kings Babylon was slowly regaining its independence,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0010.npy',
#   'Below the southeast corner window on the sixth floor was a large carton of books'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0068.npy',
#   'taken at the time of his arrest.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0015.npy',
#   'There is, however, a large amount of material available in his writings'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0062.npy',
#   'followed the same route as the Marsalis bus through downtown Dallas, except that it continued west on Elm,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0010.npy',
#   '(two) testimony of firearms identification experts establishing the identity of the murder weapon,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0132.npy',
#   'He continued his efforts to reverse the discharge by petitioning the Navy Discharge Review Board,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0058.npy',
#   'which was the possibility of an attempt against the person or safety of the President.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0004.npy',
#   "In the many weeks since that time the Congress has devoted itself to the arduous task of formulating legislation necessary to the country's welfare."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0208.npy',
#   'they sounded one Burgess, a guard on the South-Eastern Railway, a line by which large quantities of bullion were sent to the Continent.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0041.npy',
#   "Oswald's diary reports that he married his wife shortly after his proposal of marriage to another girl had been rejected."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0143.npy',
#   'each containing two notes, many of the sheets suitable for engraving any kind of note from one thousand pounds downwards.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0436.npy',
#   'The Germans maintain that it is the ruin of the Tower of Babel.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0363.npy',
#   'and there on June thirteen, three twenty-three B.C., he met his death.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0311.npy',
#   'His extensive business had been carried on by fraud.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0046.npy',
#   "went out to the garage to paint some children's blocks, and worked in the garage for half an hour or so."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0197.npy',
#   'No idleness was permitted among the inmates. Trades were taught, or prisoners were allowed to follow their own if suitable.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0173.npy',
#   'for the regulation of transportation by water, for the strengthening of our Merchant Marine and Air Transport,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0074.npy',
#   'Their actions demonstrate that the President and the Nation can expect courage and devotion to duty from the agents of the Secret Service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0109.npy',
#   "Whatever problems may have been created by Lee's home life in Louisiana and Texas,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0102.npy',
#   'The Guards, headed by Lord Adolphus Fitz Clarence, now reinforced the police, and the conspirators gave way.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0056.npy',
#   'in his intense desire to join the Marines and get away from his surroundings and his mother.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0301.npy',
#   'He had entered the house as clerk in eighteen hundred;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0253.npy',
#   'that the job of protecting the President has not been and cannot be exclusively the responsibility of the Secret Service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0242.npy',
#   'I was startled by the sharp report or explosion,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0374.npy',
#   'It was nearly impossible for them to exercise a very close supervision over the whole of the prisons of the country.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0086.npy',
#   'He then took to forging bank-notes, and was arrested as I have described above.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0107.npy',
#   'They saw a man coming south on Patton with a revolver held high in his right hand. According to Callaway, the man crossed to the west side of Patton.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0153.npy',
#   'In the planning document currently under review by the Bureau of the Budget, the Department recommends that it be permitted to hire five qualified persons, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0047.npy',
#   'He observed shredded brain tissue and, quote, considerable slow oozing, end quote, from the latter wound,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0078.npy',
#   "Presidential Assistants David F. Powers and Kenneth O'Donnell sat in the right and left jump seats, respectively."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0226.npy',
#   'Only a few have vied with Cannon in fiendish cruelty and brutality.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0184.npy',
#   'who might, quote, lead an expedition to some of these other islands and free them too, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0329.npy',
#   'their crimes follow in the lines of others already found, and often more than once, in the calendars.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ024-0001.npy',
#   'The Fireside Chats of Franklin Delano Roosevelt, by Franklin D Roosevelt'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0163.npy',
#   'Thus the wards, which, as I have said, were left in complete darkness, were now to be lighted with gas; and after this most salutary addition,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0065.npy',
#   'or female convicts ordered for execution.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0020.npy',
#   'Marina Oswald related the events which followed, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ032-0257.npy',
#   'When she started to open the blanket, she saw the stock of the rifle.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0206.npy',
#   'The Soviets have committed crimes unsurpassed even by their early day capitalist counterparts, the imprisonment of their own peoples,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ038-0273.npy',
#   'Joseph D. Nicol,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0168.npy',
#   'denoting that they came from a concourse of boys and girls already assembled in the best places, made my blood run cold.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0248.npy',
#   "Clifton C. Carter, riding in the Vice President's follow-up car a short distance behind,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0083.npy',
#   'Barbara Jeanette and Virginia Davis viewed a group of four men in a lineup and each one picked Oswald as the man who crossed their lawn while emptying his pistol.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ009-0143.npy',
#   'He sat on a bench before the pulpit, -- the hideous condemned pew had been swept away, -- and never once raised his eyes during the service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0196.npy',
#   'According to Captain Lawrence, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0168.npy',
#   'One of the police officers assigned to the corner of Elm and Houston Streets for the Presidential motorcade, W. E. Barnett,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0051.npy',
#   "The President's automobile was specially designed nineteen sixty-one Lincoln convertible"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ006-0199.npy',
#   'the most popular being the "Times," "Morning Herald," and "Morning Chronicle"; on Sunday the "Weekly Dispatch," "Bell\'s Life," and the "Weekly Messenger."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0237.npy',
#   'He apparently concluded that the United States offered, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0108.npy',
#   'It was soon ascertained that the wife had gone off in a cab with a quantity of luggage.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0196.npy',
#   'These antics may have been assumed to bear out the plea of insanity set up in his defense,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0386.npy',
#   'many of the most abandoned murderers snore peacefully their eight hours, even on the night immediately preceding execution.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0152.npy',
#   'This was the seven hundred block of North Beckley'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0137.npy',
#   'there have been references to the numerous discussions between Secret Service representatives and the Dallas Police Department.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0117.npy',
#   'On the other occasion, the President halted the motorcade to speak to a Catholic nun and a group of small children.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ032-0232.npy',
#   'The dates surrounding the taking of this picture and the purchase of the rifle'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0233.npy',
#   'Twice a week there was a wine and beer club held at night, which lasted till two or three in the morning.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0169.npy',
#   'the same corner where Brennan was sitting on a concrete wall.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0304.npy',
#   'The sheriff demanded four shillings, six pence for his liberate, the jailer six shillings, ten pence more, and the turnkey two shillings;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0253.npy',
#   'The city was spared; the great walls were left standing; the daily sacrifices were continued in the temples, and Cyrus made his home in the royal palace.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0230.npy',
#   'Manpower and Technical Assistance From Other Agencies'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0001.npy',
#   "Report of the President's Commission on the Assassination of President Kennedy. The Warren Commission Report. By The President's Commission on the Assassination of President Kennedy."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0102.npy',
#   'When Oswald entered the rear door of the Depository Building, he was about fifty feet ahead of Frazier.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0201.npy',
#   'in the locality to assure adequate manpower for this task, as it is now doing.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0164.npy',
#   'who had devoted all his talent and all his energies for some seventeen years to the fabrication of false bank-notes.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ027-0002.npy',
#   'Biology. Chapter ten. Morphology and Embryology, Part One.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0003.npy',
#   'Chapter eight. The Protection of the President. Part four.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ038-0010.npy',
#   'a recessed area extending about fifteen feet between the sidewalk and the front door of his store.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ005-0102.npy',
#   'Upon these and the private visitations made by various members the Society obtained the facts,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0214.npy',
#   '(four) carried the rifle into the Depository Building, concealed in the bag;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0087.npy',
#   'or make signs; or the chances of recognizing or being recognized were reduced to a minimum by the use of a mask.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0255.npy',
#   'approximately twenty or twenty-five minutes after the shots were fired.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ024-0143.npy',
#   'You and I will do our part.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0183.npy',
#   'The story goes, that about eighteen twenty-eight'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ001-0088.npy',
#   'were the leaders in this luckless change, though our own Baskerville, who was at work some years before them, went much on the same lines;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0267.npy',
#   'at any time while in travel status.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ025-0152.npy',
#   'So that I know not where we can hope to find any absolute distinction between animals and plants, unless we return to their mode of nutrition'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ046-0159.npy',
#   'accumulated over a twenty-year period, some of which included more than one individual.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0104.npy',
#   'slender, weighing about one sixty-five pounds, about five foot ten inches tall, and in his early thirties.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0122.npy',
#   'The Dallas Police Department furnished the Commission with pictures of the men who appeared in the lineups with Oswald,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0273.npy',
#   'Tarpey was caught through his wife,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0132.npy',
#   'and he with his father arranged that a messenger should call for the stuff with forged credentials, and anticipating the rightful owner.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0159.npy',
#   'The Commission recommends that prompt and favorable consideration be given to this request.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0373.npy',
#   "The mutineers were of the same stamp as the crew of the 'Flowery Land'"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ023-0062.npy',
#   'and which could not be met by merely local action.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0078.npy',
#   'The effect of a four-power telescopic sight on the difficulty of these shots was considered in detail'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ026-0063.npy',
#   'The food supply of the higher plant, like that of the animal, is the source of the required matter and energy,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ009-0231.npy',
#   'Although these objectionable practices had disappeared,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0106.npy',
#   "Much of Lawson's time was taken with establishing adequate security over the motorcade route and at the two places where the President would stop,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0179.npy',
#   'speaking through their government.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0297.npy',
#   'and that clever schemer sent an elaborate letter of instructions how to ask for the money.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ043-0174.npy',
#   "While there are differences between the two events as far as Oswald's actions and planning are concerned, there are also similarities that should be considered."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ013-0030.npy',
#   'The captain and crew, however, got safely to Jamaica, and so to England; the captain dying on the voyage home.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0070.npy',
#   'The other side retorted that the system of associated labor was most costly, so many officers being required to maintain the discipline of silence;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ044-0035.npy',
#   'This is suggested by his misleading and sometime untruthful statements in his letters to Mr. V. T. Lee,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0288.npy',
#   'To do this seeming to him a light matter, he mutilated himself in a way that was utterly without remedy.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0027.npy',
#   'Escape seemed absolutely hopeless,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0120.npy',
#   'and for reporting such events as a change in leadership or dogma which indicate that the group may present a danger to the President.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0380.npy',
#   'The prophecy of the Hebrew Isaiah was fulfilled:'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0172.npy',
#   "questions inevitably arise as to the scope of each agency's authority and responsibility."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0204.npy',
#   'with his head resting on his hands, looked up and observed calmly, "Go along, clock; come along, gallows."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0399.npy',
#   'Wainwright was allowed a cigar the night before execution, which he smoked in the prison yard, walking up and down with the governor, Mr. Sydney Smith.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0119.npy',
#   'and possessed of an education very much beyond the rank of life to which he originally belonged."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0127.npy',
#   'or for detention pending court appearance or commitment to a child-caring or custodial institution such as a training school.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0290.npy',
#   'he came in this plight before Darius.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0334.npy',
#   'Unusual precautions were taken upon this occasion, as some fresh outrage was apprehended.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0183.npy',
#   'that the government should assume the responsibility of providing a means by which the credit of the nation might be controlled,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0367.npy',
#   'The priests of the temple of Bel, so a story tells us,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0233.npy',
#   "and when one of the city's clinics did find room to handle him,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0149.npy',
#   'is essential. This would help to eliminate varying interpretations of Secret Service instructions by different local law enforcement representatives. For example,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0112.npy',
#   'At his own request,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0020.npy',
#   'In eighteen thirteen'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0046.npy',
#   'It is true that while business and industry are definitely better our relief rolls are still too large.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0060.npy',
#   'The Nature of the Shots'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0040.npy',
#   'When asked later whether it might have been Mr. Johnson, she said, quote, Yes, no.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ006-0233.npy',
#   'The prisoners in this way administered serious punishment on one another. Black eyes and broken noses were always to be seen.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0028.npy',
#   'Various acts were also passed to consolidate and amend previous jail acts.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0295.npy',
#   'The increase of bank forgeries, and its cause, I referred to in a previous chapter.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ027-0053.npy',
#   'The most striking fact of similar structure among plants and among animals is the existence of a common general plan in any group.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0178.npy',
#   'He thought the new alternative would have its best chance to be accepted after, quote, conflict between the two world systems leaves the world country'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ025-0043.npy',
#   'The essential character of vegetable life is the exhalation of oxygen, which is effected through the agency of light.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0329.npy',
#   'every prison was ordered to keep up an infirmary, and the medical supervision was to be strict and continuous.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0190.npy',
#   'A great empire which had existed for more than three thousand years was brought to an end.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0167.npy',
#   'Question: What did you say to that?'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0205.npy',
#   'On the dread morning he came out to execution quite gaily, and tripped up the stairs to the scaffold.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0048.npy',
#   'so subversive of meditation, so disturbing to the thoughts;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0199.npy',
#   'Whether he thought about assassinating the President over the weekend can never be known, but it is reasonably certain'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ009-0237.npy',
#   'the poor criminal rose straight upon his feet, with the hangman on his shoulders, and immediately loosened the rope with his fingers.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0102.npy',
#   'Within minutes of the assassination, Brennan described the man to the police.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0030.npy',
#   'The bank had been conducted on false principles;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ026-0070.npy',
#   'Of the substances the solids (salts, etc.) must be dissolved in water before they can be taken in.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ001-0122.npy',
#   'that he has a five, an eight, or a three before him, unless the press work is of the best:'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ026-0126.npy',
#   'as a preliminary to the real processes of nutrition.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ025-0041.npy',
#   'and carbonic acid containing carbon and oxygen.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0041.npy',
#   'Motorcycles. -- Dallas police motorcycles preceded the pilot car.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0072.npy',
#   'to Murphy and Elm three times, averaging six point five minutes for the three trips.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ044-0115.npy',
#   'he felt that this was a great man that he had received the letter from, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0338.npy',
#   'While the Babylonians, crowding to the walls, did their best to resist the Persian assault,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0271.npy',
#   'and was rendered insensible by chloroform, after which he was bound and the precious stones stolen.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0120.npy',
#   'As my Russian improves I become increasingly conscious of just what sort of a society I live in.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0181.npy',
#   'that too much emphasis is placed by both on the investigation of specific threats by individuals and not enough on dangers from other sources.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0061.npy',
#   'No beds were issued, only two rugs per prisoner.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0219.npy',
#   'Frazier testified that the rifle was accurate, that it had less recoil than the average military rifle'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0241.npy',
#   "President Johnson emphasized Youngblood's instantaneous reaction after the first shot:"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0005.npy',
#   'There had been a pause in legislation, except of a permissive kind. The second and third Victoria, cap. fifty-six'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0139.npy',
#   'he subsequently testified before a Commission staff member and, when shown two photographs of Oswald, stated that they were photographs of the man he saw.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0170.npy',
#   'There are two great representatives of power in the world,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0222.npy',
#   'Much bitterness of feeling is evidently engendered, and the corporation grows more and more angry with the inspectors.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0090.npy',
#   'He was fond of restoring the ruined temples of the old Babylonian cities,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0013.npy',
#   'Having recently heard the sounds of rifles while on a hunting trip, Baker recognized the shots as that of a high-powered rifle; Quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ046-0200.npy',
#   'Secret Service requests to other agencies for intelligence information'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0107.npy',
#   'will be spent for actually creating new work and not for building up expensive overhead organizations here in Washington.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ038-0220.npy',
#   "Oswald had paid the first month's rent in advance on March two, nineteen sixty-three,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0344.npy',
#   'The ceremony, which was witnessed by only a few officials and representatives of the press, was performed with the utmost decency and decorum.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0171.npy',
#   'I found that the paper sack found on the sixth floor and the sample'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0258.npy',
#   'Hence the frequent cases of drunkenness, of which no notice was taken, unless people grew riotous in their cups'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ032-0253.npy',
#   'From September twenty-four, nineteen sixty-three, when Marina Oswald arrived in Irving from New Orleans, until the morning of the assassination,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ043-0181.npy',
#   'that such concern is an important factor to consider in assessing possible motivation for the assassination.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0085.npy',
#   'Since the Dallas doctors directed all their efforts to controlling the massive bleeding caused by the head wound, and to reconstructing an airway to his lungs,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0077.npy',
#   'my direct services to him at that moment would have interfered with the action of the team which was in progress, end quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0052.npy',
#   '(three) transports awaiting removal to the colonies, and (four) capital convicts, condemned to death and awaiting execution.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0097.npy',
#   'whom she compared to, quote, a puppy dog that everybody kicked, end quote, had a lot of good qualities, in spite of the fact that, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0131.npy',
#   'is not fully supporting the recovery effort of his government.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0064.npy',
#   '"You have for the same reason," he goes on, "no right to ruin his habits by compelling him to be idle,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0232.npy',
#   'a sound as if the ocean had suddenly broken through some ancient boundary, against which its ever restless billows had for ages battered;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ027-0091.npy',
#   "See, then, the difference between man's mode of working and Nature's."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0267.npy',
#   'On the contrary, the prevailing sentiment was one of satisfaction at the success of the spectacle.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0091.npy',
#   'The spoil was fairly divided; part of the notes were disposed of to a traveling "receiver," who passed over to the Continent and there cashed them easily.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0072.npy',
#   "Dr. Clark did not see any other hole or wound on the President's head."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0128.npy',
#   "they with Brunt and Tidd scorned the ordinary's ministrations,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0162.npy',
#   'Consecutive bullets fired from the revolver by the FBI experts could not be identified as having been fired from that revolver.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0028.npy',
#   'Frazier told her that Oswald had come home to get curtain rods.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ029-0204.npy',
#   'Two days later, a local Republican leader called for a "civilized nonpartisan" welcome'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0106.npy',
#   'You could have picked him out without identifying him by just listening to him.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0054.npy',
#   'A very curious and, in its way, amusing circumstance in connection with this case was the offer of a certain Italian,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0135.npy',
#   'but I am jealous of the right of every citizen to call to the attention of his or her government'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ026-0078.npy',
#   'Entering the chlorophyll bodies, the kinetic energy of sunlight is applied to the decomposition of carbon dioxide and water.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0017.npy',
#   'Instead of the give and take of free individual contract,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0054.npy',
#   'He had been proceeding toward the rear of the lunchroom.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0041.npy',
#   'The whole of these seventeen had, however, a common airing-yard, and took their exercise there at the same time,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ023-0043.npy',
#   'I want to talk with you very simply about the need for present action in this crisis'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0011.npy',
#   'and took the instrument out to a clerk with the ink not dry.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0145.npy',
#   'and no written description of the role the local police were expected to perform.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0279.npy',
#   'after which he commanded his servants to tell no one what had come to pass, while he himself pondered the matter.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0188.npy',
#   'Oxford expressed little anxiety or concern.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0026.npy',
#   'Moreover, the partners were sober, steady men, who paid unremitting attention to business.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0016.npy',
#   'The Presidential limousine.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ013-0130.npy',
#   'where Ashley produced four silver spoons, and begged that his initials might be engraved upon them.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0188.npy',
#   'The eyes of the future became the eyes of God.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ001-0129.npy',
#   'the lateral compression of his letters renders necessary.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0110.npy',
#   "Whaley believes that Oswald's conduct did not aid him in his identification, quote, because I knew he was the right one as soon as I saw him."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ013-0221.npy',
#   "that he could not resist the opportunity for robbery offered him by his situation at Lord William Russell's; that when vexed with his master"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0186.npy',
#   'He must have planned his attack at the very latest prior to Thursday morning when he spoke to Frazier.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0125.npy',
#   'it was natural that the workers should seek and obtain a statutory declaration of their constitutional right'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0178.npy',
#   "A psychological human figure-drawing test corroborated the interviewer's findings that Lee was insecure and had limited social contacts."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0114.npy',
#   "Brennan's description should also be compared with the eyewitness description broadcast over the Dallas police radio at one:twenty-two p.m."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0295.npy',
#   'When the council had decided, the news was conveyed to Newgate by the Recorder, who made his "report," as it was called.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0259.npy',
#   'he confessed that his whole life had been a gigantic mistake, and he was ready to make what atonement he could.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ019-0321.npy',
#   'The infliction of punishment more or less uniform was thus aimed at.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ001-0048.npy',
#   'his letter is admirably clear and regular, but at least as beautiful as any other Roman type.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ014-0115.npy',
#   'and they had given information to the police.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0195.npy',
#   'He smiled continually, and when the indictment was read, burst into loud and discordant fits of laughter.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0135.npy',
#   'Russell confirmed this statement in a sworn affidavit for the Commission.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0139.npy',
#   'under forty shillings arising within the city.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0091.npy',
#   'It is questionable whether such criteria would have resulted in the referral of Oswald to the Secret Service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0049.npy',
#   'and the curtailment of rank stock speculation through the Securities Exchange Act.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ047-0193.npy',
#   'and so advised the Dallas office in the ordinary course of business.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0158.npy',
#   'the Department hopes to design a practical system which will fully meet the needs of the Protective Research Section of the Secret Service.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0028.npy',
#   'He saw him empty the gun and throw the shells into some bushes on the southeast corner lot.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0103.npy',
#   'This description most probably led to the radio alert sent to police cars at approximately twelve:forty-five p.m., which described the suspect as white,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0209.npy',
#   'at least for a sufficient number of seconds to gain a, quote, general impression, end quote, of the lack of any unusual activity.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0124.npy',
#   'Marina Oswald thought he did so in order to emphasize his importance.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0201.npy',
#   'unlimited drink was not denied them provided it was obtained in regulated quantities at one time.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0025.npy',
#   'McWatters was sure that he left the checkpoint on time'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0151.npy',
#   'and issued his initial orders at twelve:thirty p.m.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0149.npy',
#   'but I had to change my character a great deal in order to maintain a more or less peaceful family life. End quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0257.npy',
#   'Searches were made certainly, but they were too often superficial, or they might be evaded by a trifling bribe.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0157.npy',
#   'When he left home that morning, Marina Oswald, who was still in bed, suggested that he wear a jacket.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0044.npy',
#   'Motorcycles. -- Next came four to six motorcycle policemen whose main purpose was to keep the crowd back.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0097.npy',
#   'and at the time of the robbery there were still six thousand pounds worth in the warehouse.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0186.npy',
#   'which will bring about the final destruction of the capitalist system, and indicated that'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0082.npy',
#   'it was recognized that the cameo was genuine, and that it bore the likeness of the great King.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0175.npy',
#   'could possibly make a choice between them, there is no choice,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ046-0026.npy',
# ...
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ042-0087.npy',
#   'He stated that he had volunteered to give Soviet officials any information that he had concerning Marine Corps operations, and intimated'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0491.npy',
#   'then a second wall still higher, a third and fourth and a fifth, each stronger and higher than the others,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0141.npy',
#   'Felons who could pay the price were permitted, irrespective of their character or offenses,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0081.npy',
#   'There was no Federal criminal jurisdiction over the assassination of President Kennedy.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0014.npy',
#   'John Hogan, the murderer of a Mr. Odell, an attorney who resided in Charlotte Street, Rathbone Place,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0248.npy',
#   'But this boon of toil was denied to all but a very limited number.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0307.npy',
#   'but as yet no suggestion was made to provide prison uniform.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ048-0172.npy',
#   'At the two places in Dallas where the President would remain for a period of time, Love Field and the Trade Mart,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ016-0016.npy',
#   "There is an attempt at escape mentioned in Mr. Wakefield's book, which might have been an intended suicide."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0095.npy',
#   'is found to be owing to want of cleanliness and fresh air in the several jails,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0021.npy',
#   'to permit its removal on those occasions when the President wished to ride in an open car.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ013-0197.npy',
#   'Mr. Phillips, who led in the case, went to the other extreme,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ005-0060.npy',
#   'The Society did not limit its remarks to the description of what had already been done'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0164.npy',
#   "The most affecting and distressing scene was at Green Arbor Lane, just opposite the debtors' door of the prison."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0075.npy',
#   'She is described as a well-made little woman, something more than thirty years of age, of a pale complexion and not disagreeable features.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0155.npy',
#   'He always wanted to play the red pieces in chess because, as he said in an apparently humorous context,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0013.npy',
#   'As regards the first, I find that in seventeen eighty-six'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0032.npy',
#   "Although he was reclining in his wife's arms, he lurched forward in an effort to stand upright and get out of the car, but he collapsed again."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ032-0222.npy',
#   'Moreover, Shaneyfelt testified that in his opinion the photographs were not composites of two different photographs'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0159.npy',
#   'In his person he was neat and fastidious;'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0195.npy',
#   "and of these Bishop and Williams, who were guilty of many peculiar atrocities, ended their murderous careers in front of the debtors' door at Newgate."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0364.npy',
#   'It will be remembered that she made a statement which led to the empaneling of a jury of matrons, who decided that there was no cause for an arrest of judgment.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ017-0169.npy',
#   'The Home Secretary, in a letter to the Lord Chief Baron, stated that, quote, although the facts are full of suspicion against Smethurst,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ031-0129.npy',
#   'The agents moved a nurse and patient out of a nearby room, lowered the shades, and took emergency security measures to protect the Vice President.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0033.npy',
#   'asked for a transfer and got off at the same place in the middle of the block where the lady did.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ034-0120.npy',
#   'the police radio reported that, quote, an eyeball witness, end quote, described the suspect in the Tippit shooting as, quote, a white male,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ006-0285.npy',
#   'which numbers of well-meaning but inquisitive people were anxious to witness.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ046-0147.npy',
#   'were broad and flexible. All material is and was desired, accepted, and filed if it indicated or tended to indicate'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ043-0178.npy',
#   'as, in fact, one of them did appear after the assassination.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ047-0099.npy',
#   'Quigley recalled that Oswald was receptive when questioned about his general background'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ017-0064.npy',
#   "he made use of the remarkable words, quote, If it is necessary for my soul's sake to confess this murder,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0195.npy',
#   'the great Chief Justice White said:'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0195.npy',
#   "Satisfying himself that Oswald was missing, Truly obtained Oswald's address, phone number, and description from his employment application card."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ039-0171.npy',
#   'On the second series they required five point one five, six point four five, and seven seconds.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0166.npy',
#   '"What do you know of our clerk?" asked Mr. Denison of his lordship. "Only that he is a capital fellow, who gives the best dinners and balls in town."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ044-0106.npy',
#   'and Benjamin J. Davis honorary membership cards in his nonexistent New Orleans chapter of the Fair Play for Cuba Committee,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0248.npy',
#   'He told his story with perfect coolness and self-possession, but in a grave and serious tone.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0344.npy',
#   'all chances of classification and separation vanished, and the greatest evils remained untouched.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ036-0048.npy',
#   'She boarded the Marsalis bus at St. Paul and Elm Streets to return home. She testified further, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0218.npy',
#   'Thoughts of his personal difficulties must have been at least partly on his mind when he went to Irving on Thursday night and told his wife that he was lonely,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ047-0103.npy',
#   'who was involved, what occurred, he was reticent to furnish information,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ041-0182.npy',
#   'and believed that our Government did not have, quote, too much to offer, end quote, but was not in favor of, quote, the Communist way of life, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ005-0055.npy',
#   'or a dungeon above or below the gate of a town, to the first attempts at systematic reconstruction carried out under the advice and supervision of Howard.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ043-0072.npy',
#   'Even though he told his wife that he had been fired, he voluntarily left on October eight, nineteen sixty-two, and moved to Dallas.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ038-0200.npy',
#   'the city jail is located at the end of the bridge through which we always passed on going to the city (right in the beginning of the city after crossing the bridge).'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ043-0071.npy',
#   'His performance for that company was satisfactory.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0148.npy',
#   'had invariably been visited with the death penalty, and which was of a distinctly fraudulent nature.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0018.npy',
#   'he wore gold-rimmed eye-glasses and a gold watch and chain.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0004.npy',
#   'The reasons for this change were fully set forth in a previous chapter.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0030.npy',
#   'Our first problem was, of course, the banking situation because, as you know, the banks had collapsed.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0113.npy',
#   'This point was ably made in the nineteen oh two debate by Senator George F. Hoar, the sponsor of the Senate bill, quote,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ025-0105.npy',
#   'On the other hand, those plants, such as the fungi,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0264.npy',
#   'Among the daily visitors were members of the criminal classes still at large,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0280.npy',
#   'On June eighteen fifty the Queen was once more subjected to cowardly outrage, the offender being a Mr. Pate, a gentleman by birth,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0234.npy',
#   'for some reason the record does not show, advantage was never taken of the chance afforded to Oswald.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ006-0234.npy',
#   'More cruel injuries were common enough, which did not result from honest hand-to-hand fights.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ038-0136.npy',
#   'In concluding that Oswald was carrying a rifle in the paper bag on the morning of November twenty-two, nineteen sixty-three,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0246.npy',
#   'which would permit it to provide adequate protective manpower for all situations.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0188.npy',
#   'Sokolow said that although Lee was, quote, presumably disinterested in school subjects he operates on a much higher than average level, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0132.npy',
#   'An elaborate machinery planned for the protection of the trader, and altogether on his side, had long existed for the recovery of debts.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0288.npy',
#   'and was seen to be busily engaged in washing down the house with bucket and mop.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ028-0474.npy',
#   'It too was surmounted with towers.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ010-0299.npy',
#   'caused much excitement at the time on account of the magnitude of the fraud, and the seeming probity of the culprit.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ021-0009.npy',
#   'with a greater certainty of the employment of labor at a reasonable wage and of more business at a fair profit.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0220.npy',
#   'The four waited patiently for their opportunity,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ012-0108.npy',
#   'There was a hunt for the two well-known house-breakers, who were eventually heard of at a lodging in Kennington.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ002-0146.npy',
#   'The activity as well as the futility of these courts may be estimated from the statement given by Neild'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ030-0119.npy',
#   'The crowds were so dense that Special Agent Clinton J. Hill'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ027-0090.npy',
#   'modified more and more through successive generations by the necessities of different modes of life.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ008-0188.npy',
#   'Every window and roof which could command a view of the horrible performance was occupied.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0025.npy',
#   'More precise clues to the murderer were not long wanting; indeed the readiness with which they were produced and followed up'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0210.npy',
#   'Those who manufactured and those who passed had no direct dealings with each other.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ029-0167.npy',
#   "On the morning of the President's arrival,"],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ006-0042.npy',
#   'Relapse was rapid and inevitable, so that the latter state of the prison was worse than the first.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ015-0154.npy',
#   'When the crash came there were pensioners and other recipients of his bounty who could not believe'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ033-0003.npy',
#   'The rifle in the building.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ003-0118.npy',
#   'Various punishments were inflicted, the heaviest of which was standing in the pillory.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0114.npy',
#   'what this bill means to punish is the crime of interruption of the Government of the United States and the destruction of its security by striking down the life'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ035-0144.npy',
#   "Oswald's departure from building."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ004-0161.npy',
#   '"the indescribable stench," presented together a concentration of the utmost misery and the utmost guilt.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0153.npy',
#   'is generally known to all the worst men in the country; not only without the inclination, but almost without the ability of returning to an honest life."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ040-0132.npy',
#   'with Puerto Ricans and Negroes and everything, end quote.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0018.npy',
#   'Scoggins saw him and heard him mutter either "Poor damn cop" or "Poor dumb cop."'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ011-0121.npy',
#   'Suddenly, after being at the lowest depths, he emerged, and was found by his friends living in comfort in the Waterloo Road.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0236.npy',
#   'Sometimes the stench in hot weather is said to be very bad.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ022-0194.npy',
#   'Never since my inauguration in March, nineteen thirty-three, have I felt so unmistakably the atmosphere of recovery.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ007-0077.npy',
#   'One of these were the criminal lunatics, who were at this time and for long previous continuously imprisoned there.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ037-0168.npy',
#   "Nicol differed with the FBI experts on one bullet taken from Tippit's body."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ029-0101.npy',
#   "For the President's return to Love Field following the luncheon, the agents selected the most direct route, which was approximately four miles."],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ050-0025.npy',
#   'or from which it derives assistance and support.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ045-0063.npy',
#   'Oswald apparently wished to continue practicing his own Russian with her. Lieutenant Martello of the New Orleans police testified'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ018-0229.npy',
#   'The day his father died he got the keys of his private bureau, opened it, and took out the authentic will.'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ049-0209.npy',
#   'The Commission was not asked to apply itself as did the Hoover Commission in nineteen forty-nine,'],
#  ['DUMMY/LJSpeech-1.1/encoded_audio_en/emasrc/LJ029-0201.npy',
#   'Meanwhile, on November seventeen'],
#  ...]

# %%
from text import text_to_sequence, cmudict
from text.converters import text_to_arpabet, check_arpabet

cmudict_path = params_v4.cmudict_path
cmu_dict = cmudict.CMUDict(cmudict_path)

for i in range(len(train_dataset.filepaths_list)):
    _, text = train_dataset.filepaths_list[i]
    text_norm = text_to_arpabet(text, dictionary=cmu_dict, cleaner_names=["english_cleaners_v2"])
    text_norm = " ".join(text_norm)
    text_norm = text_to_sequence(text_norm, dictionary=cmu_dict, cleaner_names=["english_cleaners_v2"])
    alphabet = [i for i in range(12,64)]
    for elem in text_norm:
        if elem in alphabet:
            print([symbols_[e] for e in text_norm])
            break

# %%
from utils import parse_filelist, intersperse, normalize_channel
import torch

add_blank = params_v4.add_blank

text_norm = text_to_arpabet(sentences[0], dictionary=cmu_dict, cleaner_names=["english_cleaners_v2"])
text_norm = " ".join(text_norm)
print(text_norm)
text_norm = text_to_sequence(text_norm, dictionary=cmu_dict, cleaner_names=["english_cleaners_v2"])
if add_blank:
    text_norm = intersperse(
        text_norm, len(symbols)
    )  # add a blank token, whose id number is len(symbols)
text_norm = torch.IntTensor(text_norm)
text_norm
# Out:
# {AH1 N} giorno {EH1 R AH0} {L IY1} indaffarato {IY1} nervoso tra {L AH0} {AA1 R N IY0} {IY1} {AY1} canali
# tensor([148,  74, 148, 119, 148,  44, 148,  46, 148,  52, 148,  55, 148,  51,
#         148,  52, 148,  94, 148, 130, 148,  73, 148, 117, 148, 113, 148,  46,
#         148,  51, 148,  41, 148,  38, 148,  43, 148,  43, 148,  38, 148,  55,
#         148,  38, 148,  57, 148,  52, 148, 113, 148,  51, 148,  42, 148,  55,
#         148,  59, 148,  52, 148,  56, 148,  52, 148,  11, 148,  57, 148,  55,
#         148,  38, 148, 117, 148,  73, 148,  66, 148, 130, 148, 119, 148, 112,
#         148, 113, 148,  86, 148,  40, 148,  38, 148,  51, 148,  38, 148,  49,
#         148,  46, 148], dtype=torch.int32)

# %% [markdown]
# # Create hearing samples

# %%
import numpy as np
import soundfile as sf
import torchaudio



def change_audio_speed(input_path, output_path, speed=1.25):
    """
    Change the playback speed of an audio file.

    Parameters:
    - input_path: Path to the input audio file.
    - output_path: Path to save the modified audio file.
    - speed: Speed factor (e.g., 1.5 for 1.5x speed).
    """
    waveform, sr = torchaudio.load(input_path)
    effects = [["tempo", str(speed)]]  # faster, pitch preserved
    waveform, sr = torchaudio.sox_effects.apply_effects_tensor(waveform, sr, effects)
    torchaudio.save(output_path, waveform, sr)

# %% [markdown]
# ## ljspeech

# %%
import os
import shutil
import random


dataset = "LJSpeech-1.1"
speaker = ""
ckpt_name = "grad_3000"
artts_folder = ""


filestems = []

dest_dir = DATA_DIR / f"{dataset}_listen"
os.makedirs(dest_dir, exist_ok=True)

# Define the source directory, destination directory, and list of filestems
v1_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v1_1" / ckpt_name
v4_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v4" / ckpt_name
sparc_dir = DATA_DIR / dataset / artts_folder / speaker / "hifigan_pred" / "sparc"

src_dir = DATA_DIR / dataset / "wavs" ## Depends on the dataset structure

# %%
# get the list of filestems
def pick_random_files(directory, num_files=9):
    # List all files in the directory
    all_files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    
    # Pick random files
    random_files = random.sample(all_files, min(num_files, len(all_files)))
    
    return random_files

random_files = pick_random_files(sparc_dir)
filestems = [Path(f).stem for f in random_files]
filestems = sorted(filestems)
print(f"Picked {len(filestems)} random files: {filestems}")
# Out:
# Picked 9 random files: ['LJ004-0152', 'LJ008-0258', 'LJ008-0278', 'LJ013-0164', 'LJ021-0066', 'LJ021-0145', 'LJ022-0023', 'LJ042-0129', 'LJ045-0230']

# %%
#filestems_list = []
#sources_list = []
#suffixs_list = []
#for filestem in filestems:
#    # Define source files
#    v1_file = v1_dir / f"{filestem}_decoder.wav"
#    v4_file = v4_dir / f"{filestem}_decoder.wav"
#    sparc_file = sparc_dir / f"{filestem}.wav"
#    src_file = src_dir / f"{filestem}.wav"
#    
#    sources = ["v1_1", "v4", "sparc", "src"]
#    idx_list = [0, 1, 2, 3]
#    random.shuffle(idx_list)  #in place permutation
#    reorder_sources = [idx_list.index(i) for i in range(len(idx_list))]
#    shuffled_sources = [sources[i] for i in reorder_sources]
#
#    # Define destination files with random order but common prefix
#    dest_v1_file = dest_dir / f"{filestem}_{idx_list[0]}.wav"
#    dest_v4_file = dest_dir / f"{filestem}_{idx_list[1]}.wav"
#    dest_sparc_file = dest_dir / f"{filestem}_{idx_list[2]}.wav"
#    dest_src_file = dest_dir / f"{filestem}_{idx_list[3]}.wav"
#    
#    if v1_file.exists():
#        shutil.copy(v1_file, dest_v1_file)
#    else:
#        print(f"Warning: {v1_file} does not exist.")
#    if v4_file.exists():
#        change_audio_speed(v4_file, dest_v4_file, speed=1.25)
#    else:
#        print(f"Warning: {v4_file} does not exist.")
#    if sparc_file.exists():
#        shutil.copy(sparc_file, dest_sparc_file)
#    else:
#        print(f"Warning: {sparc_file} does not exist.")
#    if src_file.exists():
#        shutil.copy(src_file, dest_src_file)
#    else:
#        print(f"Warning: {src_file} does not exist.")
#
#    sources_list += shuffled_sources
#    filestems_list += [filestem] * 4
#    suffixs_list += [0, 1, 2, 3]

# %%
scoring_df = pd.DataFrame({
    "filestem": filestems_list,
    "source": sources_list,
    "suffix": suffixs_list,
})
#scoring_df.to_csv(dest_dir / "scores.csv", index=False)

# %%
scoring_df.head()
# Out:
#      filestem source  suffix
# 0  LJ004-0152    src       0
# 1  LJ004-0152     v4       1
# 2  LJ004-0152   v1_1       2
# 3  LJ004-0152  sparc       3
# 4  LJ008-0258  sparc       0

# %% [markdown]
# ## MNGU0

# %%
import os
import shutil
import random


dataset = "MNGU0"
speaker = "s1"
ckpt_name = "grad_3000"
artts_folder = "arttts"
#artts_folder = ""


filestems = []

dest_dir = DATA_DIR / f"{dataset}_listen"
os.makedirs(dest_dir, exist_ok=True)

# Define the source directory, destination directory, and list of filestems
v1_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v1_1" / ckpt_name
v4_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v4" / ckpt_name
sparc_dir = DATA_DIR / dataset / artts_folder / speaker / "hifigan_pred" / "sparc"

src_dir = DATA_DIR / dataset / "src_data" / speaker / "wav_16kHz" ## Depends on the dataset structure

# %%
version = "v1_1"
mngu0_summary = get_specific_summary(dataset, speaker, version, ckpt_name)
mngu0_summary.sort_values(by="pcc_gt_dec", ascending=False, inplace=True)
mngu0_summary = mngu0_summary[["filestem", "pcc_gt_dec"]]
mngu0_summary
# Out:
#             filestem  pcc_gt_dec
# 523   mngu0_s1_0898a    0.909539
# 492    mngu0_s1_0908    0.895223
# 1169   mngu0_s1_0198    0.891965
# 598    mngu0_s1_0046    0.882915
# 929   mngu0_s1_0539a    0.882166
# ...              ...         ...
# 1294  mngu0_s1_0995a    0.424694
# 1302   mngu0_s1_0307    0.406906
# 1230   mngu0_s1_0417    0.391881
# 1295   mngu0_s1_0562    0.266877
# 1272  mngu0_s1_0779a    0.239033
#
# [1312 rows x 2 columns]

# %%
n = 3
bests = mngu0_summary["filestem"].tolist()[:n]
worsts = mngu0_summary["filestem"].tolist()[-n:]
mid = mngu0_summary["filestem"].tolist()[n:-n]
mid = random.sample(mid, n)

# %%
filestems = bests + mid + worsts
filestems_types = ["best"] * n + ["mid"] * n + ["worst"] * n

# %%
filestems, filestems_types = zip(*sorted(zip(filestems, filestems_types)))
filestems = list(filestems)
filestems_types = list(filestems_types)

# %%
#filestems_list = []
#sources_list = []
#suffixs_list = []
#types = []
#for filestem, filestem_type in zip(filestems, filestems_types):
#    # Define source files
#    v1_file = v1_dir / f"{filestem}_decoder.wav"
#    v4_file = v4_dir / f"{filestem}_decoder.wav"
#    sparc_file = sparc_dir / f"{filestem}.wav"
#    src_file = src_dir / f"{filestem}.wav"
#
#    sources = ["v1_1", "v4", "sparc", "src"]
#    idx_list = [0, 1, 2, 3]
#    random.shuffle(idx_list)  #in place permutation
#    reorder_sources = [idx_list.index(i) for i in range(len(idx_list))]
#    shuffled_sources = [sources[i] for i in reorder_sources]
#
#    # Define destination files with random order but common prefix
#    dest_v1_file = dest_dir / f"{filestem}_{idx_list[0]}.wav"
#    dest_v4_file = dest_dir / f"{filestem}_{idx_list[1]}.wav"
#    dest_sparc_file = dest_dir / f"{filestem}_{idx_list[2]}.wav"
#    dest_src_file = dest_dir / f"{filestem}_{idx_list[3]}.wav"
#
#    if v1_file.exists():
#        shutil.copy(v1_file, dest_v1_file)
#    else:
#        print(f"Warning: {v1_file} does not exist.")
#    if v4_file.exists():
#        change_audio_speed(v4_file, dest_v4_file, speed=1.25)
#    else:
#        print(f"Warning: {v4_file} does not exist.")
#    if sparc_file.exists():
#        shutil.copy(sparc_file, dest_sparc_file)
#    else:
#        print(f"Warning: {sparc_file} does not exist.")
#    if src_file.exists():
#        shutil.copy(src_file, dest_src_file)
#    else:
#        print(f"Warning: {src_file} does not exist.")
#
#    sources_list += shuffled_sources
#    filestems_list += [filestem] * 4
#    suffixs_list += [0, 1, 2, 3]
#    types += [filestem_type] * 4

# %%
scoring_df = pd.DataFrame({
    "filestem": filestems_list,
    "source": sources_list,
    "suffix": suffixs_list,
    "types" : types
})
#scoring_df.to_csv(dest_dir / "scores.csv", index=False)

# %%
scoring_df.head()
# Out:
#         filestem source  suffix types
# 0  mngu0_s1_0108   v1_1       0   mid
# 1  mngu0_s1_0108  sparc       1   mid
# 2  mngu0_s1_0108     v4       2   mid
# 3  mngu0_s1_0108    src       3   mid
# 4  mngu0_s1_0198   v1_1       0  best

# %% [markdown]
# ## MSPKA

# %%
import os
import shutil
import random


dataset = "MSPKA_EMA_ita"
speakers = ['cnz', 'lls', 'olm']
speakers = sorted(speakers)
ckpt_name = "grad_3000"
artts_folder = "arttts"
#artts_folder = ""

dest_dir = DATA_DIR / f"{dataset}_listen"
os.makedirs(dest_dir, exist_ok=True)

#filestems_list = []
#sources_list = []
#suffixs_list = []
#types = []
#for speaker in speakers:
#    # Define the source directory, destination directory, and list of filestems
#    v1_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v1_1" / ckpt_name
#    v4_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v4" / ckpt_name
#    sparc_dir = DATA_DIR / dataset / artts_folder / speaker / "hifigan_pred" / "sparc"
#
#    src_dir = DATA_DIR / dataset / "src_data" / speaker ## Depends on the dataset structure
#    
#    version = "v1_1"
#    summary = get_specific_summary(dataset, speaker, version, ckpt_name)
#    summary.sort_values(by="pcc_gt_dec", ascending=False, inplace=True)
#    summary = summary[["filestem", "pcc_gt_dec"]]
#    n = 1
#    bests = summary["filestem"].tolist()[:n]
#    worsts = summary["filestem"].tolist()[-n:]
#    mid = summary["filestem"].tolist()[n:-n]
#    mid = random.sample(mid, n)
#    spk_filestems = bests + mid + worsts
#    spk_filestems_types = ["best"] * n + ["mid"] * n + ["worst"] * n
#    filestems, filestems_types = zip(*sorted(zip(spk_filestems, spk_filestems_types)))
#    filestems = list(filestems)
#    filestems_types = list(filestems_types)
#    print(filestems, filestems_types)
#
#    for filestem, filestem_type in zip(filestems, filestems_types):
#        # Define source files
#        v1_file = v1_dir / f"{filestem}_decoder.wav"
#        v4_file = v4_dir / f"{filestem}_decoder.wav"
#        sparc_file = sparc_dir / f"{filestem}.wav"
#        src_file = src_dir / f"{filestem}.wav"
#    
#        sources = ["v1_1", "v4", "sparc", "src"]
#        idx_list = [0, 1, 2, 3]
#        random.shuffle(idx_list)  #in place permutation
#        reorder_sources = [idx_list.index(i) for i in range(len(idx_list))]
#        shuffled_sources = [sources[i] for i in reorder_sources]
#    
#        # Define destination files with random order but common prefix
#        dest_v1_file = dest_dir / f"{filestem}_{idx_list[0]}.wav"
#        dest_v4_file = dest_dir / f"{filestem}_{idx_list[1]}.wav"
#        dest_sparc_file = dest_dir / f"{filestem}_{idx_list[2]}.wav"
#        dest_src_file = dest_dir / f"{filestem}_{idx_list[3]}.wav"
#    
#        if v1_file.exists():
#            shutil.copy(v1_file, dest_v1_file)
#        else:
#            print(f"Warning: {v1_file} does not exist.")
#        if v4_file.exists():
#            change_audio_speed(v4_file, dest_v4_file, speed=1.25)
#        else:
#            print(f"Warning: {v4_file} does not exist.")
#        if sparc_file.exists():
#            shutil.copy(sparc_file, dest_sparc_file)
#        else:
#            print(f"Warning: {sparc_file} does not exist.")
#        if src_file.exists():
#            shutil.copy(src_file, dest_src_file)
#        else:
#            print(f"Warning: {src_file} does not exist.")
#    
#        sources_list += shuffled_sources
#        filestems_list += [filestem] * 4
#        suffixs_list += [0, 1, 2, 3]
#        types += [filestem_type] * 4
# Out:
# ['cnz_176', 'cnz_241', 'cnz_74'] ['best', 'mid', 'worst']
# ['lls_193', 'lls_316', 'lls_372'] ['worst', 'mid', 'best']
# ['olm_190', 'olm_394', 'olm_78'] ['worst', 'mid', 'best']

# %%
scoring_df = pd.DataFrame({
    "filestem": filestems_list,
    "source": sources_list,
    "suffix": suffixs_list,
    "types" : types
})
#scoring_df.to_csv(dest_dir / "scores.csv", index=False)

# %%
scoring_df.head()
# Out:
#   filestem source  suffix types
# 0  cnz_176   v1_1       0  best
# 1  cnz_176     v4       1  best
# 2  cnz_176  sparc       2  best
# 3  cnz_176    src       3  best
# 4  cnz_241     v4       0   mid

# %% [markdown]
# ## Mocha

# %%
import os
import shutil
import random


dataset = "mocha_timit"
speakers = ["faet0", "ffes0", "fsew0", "maps0", "mjjn0", "msak0" ]
speakers = sorted(speakers)
ckpt_name = "grad_3000"
artts_folder = "arttts"
#artts_folder = ""

dest_dir = DATA_DIR / f"{dataset}_listen"
os.makedirs(dest_dir, exist_ok=True)

#filestems_list = []
#sources_list = []
#suffixs_list = []
#types = []
#for speaker in speakers:
#    # Define the source directory, destination directory, and list of filestems
#    v1_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v1_1" / ckpt_name
#    v4_dir = DATA_DIR / dataset / artts_folder / speaker  / "hifigan_pred" / "v4" / ckpt_name
#    sparc_dir = DATA_DIR / dataset / artts_folder / speaker / "hifigan_pred" / "sparc"
#
#    src_dir = DATA_DIR / dataset / "src_data" / speaker ## Depends on the dataset structure
#    
#    version = "v1_1"
#    summary = get_specific_summary(dataset, speaker, version, ckpt_name)
#    summary.sort_values(by="pcc_gt_dec", ascending=False, inplace=True)
#    summary = summary[["filestem", "pcc_gt_dec"]]
#    n = 1
#    bests = summary["filestem"].tolist()[:n]
#    worsts = summary["filestem"].tolist()[-n:]
#    mid = summary["filestem"].tolist()[n:-n]
#    mid = random.sample(mid, n)
#    spk_filestems = bests + mid + worsts
#    spk_filestems_types = ["best"] * n + ["mid"] * n + ["worst"] * n
#    filestems, filestems_types = zip(*sorted(zip(spk_filestems, spk_filestems_types)))
#    filestems = list(filestems)
#    filestems_types = list(filestems_types)
#    print(filestems, filestems_types)
#
#    for filestem, filestem_type in zip(filestems, filestems_types):
#        # Define source files
#        v1_file = v1_dir / f"{filestem}_decoder.wav"
#        v4_file = v4_dir / f"{filestem}_decoder.wav"
#        sparc_file = sparc_dir / f"{filestem}.wav"
#        src_file = src_dir / f"{filestem}.wav"
#    
#        sources = ["v1_1", "v4", "sparc", "src"]
#        idx_list = [0, 1, 2, 3]
#        random.shuffle(idx_list)  #in place permutation
#        reorder_sources = [idx_list.index(i) for i in range(len(idx_list))]
#        shuffled_sources = [sources[i] for i in reorder_sources]
#    
#        # Define destination files with random order but common prefix
#        dest_v1_file = dest_dir / f"{filestem}_{idx_list[0]}.wav"
#        dest_v4_file = dest_dir / f"{filestem}_{idx_list[1]}.wav"
#        dest_sparc_file = dest_dir / f"{filestem}_{idx_list[2]}.wav"
#        dest_src_file = dest_dir / f"{filestem}_{idx_list[3]}.wav"
#    
#        if v1_file.exists():
#            shutil.copy(v1_file, dest_v1_file)
#        else:
#            print(f"Warning: {v1_file} does not exist.")
#        if v4_file.exists():
#            change_audio_speed(v4_file, dest_v4_file, speed=1.25)
#        else:
#            print(f"Warning: {v4_file} does not exist.")
#        if sparc_file.exists():
#            shutil.copy(sparc_file, dest_sparc_file)
#        else:
#            print(f"Warning: {sparc_file} does not exist.")
#        if src_file.exists():
#            shutil.copy(src_file, dest_src_file)
#        else:
#            print(f"Warning: {src_file} does not exist.")
#    
#        sources_list += shuffled_sources
#        filestems_list += [filestem] * 4
#        suffixs_list += [0, 1, 2, 3]
#        types += [filestem_type] * 4
# Out:
# ['faet0_026', 'faet0_152', 'faet0_212'] ['mid', 'worst', 'best']
# ['ffes0_131', 'ffes0_233', 'ffes0_282'] ['best', 'worst', 'mid']
# ['fsew0_003', 'fsew0_007', 'fsew0_212'] ['mid', 'worst', 'best']
# ['maps0_116', 'maps0_200', 'maps0_416'] ['best', 'worst', 'mid']
# ['mjjn0_008', 'mjjn0_152', 'mjjn0_322'] ['best', 'worst', 'mid']
# ['msak0_002', 'msak0_008', 'msak0_282'] ['mid', 'best', 'worst']

# %%
scoring_df = pd.DataFrame({
    "filestem": filestems_list,
    "source": sources_list,
    "suffix": suffixs_list,
    "types" : types
})
#scoring_df.to_csv(dest_dir / "scores.csv", index=False)

# %%
scoring_df.head()
# Out:
#     filestem source  suffix  types
# 0  faet0_152    src       0  worst
# 1  faet0_152   v1_1       1  worst
# 2  faet0_152     v4       2  worst
# 3  faet0_152  sparc       3  worst
# 4  faet0_186  sparc       0    mid

# %% [markdown]
# # correct former mistake

# %%
import os
import shutil
import random

source2idx = {
    "v1_1": 0,
    "v4": 1,
    "sparc": 2,
    "src": 3}
sources = ["v1_1", "v4", "sparc", "src"]

#dataset = "LJSpeech-1.1"
for dataset in ["LJSpeech-1.1", "MNGU0", "MSPKA_EMA_ita", "mocha_timit"]:
    dest_dir = DATA_DIR / f"{dataset}_listen"
    old_scores_csv = dest_dir / "scores_old.csv"
    old_scores = pd.read_csv(old_scores_csv)

    bad_sources = list(old_scores["source"])
    assert len(bad_sources) % 4 == 0
    n_samples = len(bad_sources) // 4
    new_list = []
    for i in range(n_samples):
        batch_sources = bad_sources[i*4:i*4+4]
        idx_list = [source2idx[source] for source in batch_sources]
        print("idx_list",idx_list)
        reorder_sources = [idx_list.index(i) for i in range(len(idx_list))]
        print("reorder_sources", reorder_sources)
        shuffled_sources = [sources[i] for i in reorder_sources]
        print("shuffled_sources", shuffled_sources)
        new_list += shuffled_sources
    old_scores["source"] = new_list
    #old_scores.to_csv(dest_dir / "scores.csv", index=False)
# Out:
# idx_list [3, 1, 0, 2]
# reorder_sources [2, 1, 3, 0]
# shuffled_sources ['sparc', 'v4', 'src', 'v1_1']
# idx_list [2, 1, 3, 0]
# reorder_sources [3, 1, 0, 2]
# shuffled_sources ['src', 'v4', 'v1_1', 'sparc']
# idx_list [0, 3, 2, 1]
# reorder_sources [0, 3, 2, 1]
# shuffled_sources ['v1_1', 'src', 'sparc', 'v4']
# idx_list [0, 3, 1, 2]
# reorder_sources [0, 2, 3, 1]
# shuffled_sources ['v1_1', 'sparc', 'src', 'v4']
# idx_list [1, 3, 0, 2]
# reorder_sources [2, 0, 3, 1]
# shuffled_sources ['sparc', 'v1_1', 'src', 'v4']
# idx_list [3, 1, 2, 0]
# reorder_sources [3, 1, 2, 0]
# shuffled_sources ['src', 'v4', 'sparc', 'v1_1']
# idx_list [1, 3, 2, 0]
# reorder_sources [3, 0, 2, 1]
# shuffled_sources ['src', 'v1_1', 'sparc', 'v4']
# idx_list [1, 2, 3, 0]
# reorder_sources [3, 0, 1, 2]
# shuffled_sources ['src', 'v1_1', 'v4', 'sparc']
# idx_list [0, 2, 1, 3]
# reorder_sources [0, 2, 1, 3]
# shuffled_sources ['v1_1', 'sparc', 'v4', 'src']
# idx_list [0, 2, 1, 3]
# reorder_sources [0, 2, 1, 3]
# shuffled_sources ['v1_1', 'sparc', 'v4', 'src']
# idx_list [0, 2, 3, 1]
# reorder_sources [0, 3, 1, 2]
# shuffled_sources ['v1_1', 'src', 'v4', 'sparc']
# idx_list [2, 0, 3, 1]
# reorder_sources [1, 3, 0, 2]
# shuffled_sources ['v4', 'src', 'v1_1', 'sparc']
# idx_list [2, 0, 3, 1]
# reorder_sources [1, 3, 0, 2]
# shuffled_sources ['v4', 'src', 'v1_1', 'sparc']
# idx_list [2, 1, 0, 3]
# reorder_sources [2, 1, 0, 3]
# shuffled_sources ['sparc', 'v4', 'v1_1', 'src']
# idx_list [2, 0, 3, 1]
# reorder_sources [1, 3, 0, 2]
# shuffled_sources ['v4', 'src', 'v1_1', 'sparc']
# idx_list [0, 3, 1, 2]
# reorder_sources [0, 2, 3, 1]
# shuffled_sources ['v1_1', 'sparc', 'src', 'v4']
# idx_list [2, 3, 1, 0]
# reorder_sources [3, 2, 0, 1]
# shuffled_sources ['src', 'sparc', 'v1_1', 'v4']
# idx_list [0, 3, 2, 1]
# reorder_sources [0, 3, 2, 1]
# shuffled_sources ['v1_1', 'src', 'sparc', 'v4']
# idx_list [0, 1, 2, 3]
# reorder_sources [0, 1, 2, 3]
# shuffled_sources ['v1_1', 'v4', 'sparc', 'src']
# idx_list [1, 3, 0, 2]
# reorder_sources [2, 0, 3, 1]
# shuffled_sources ['sparc', 'v1_1', 'src', 'v4']
# idx_list [2, 3, 0, 1]
# reorder_sources [2, 3, 0, 1]
# shuffled_sources ['sparc', 'src', 'v1_1', 'v4']
# idx_list [1, 0, 2, 3]
# reorder_sources [1, 0, 2, 3]
# shuffled_sources ['v4', 'v1_1', 'sparc', 'src']
# idx_list [3, 0, 2, 1]
# reorder_sources [1, 3, 2, 0]
# shuffled_sources ['v4', 'src', 'sparc', 'v1_1']
# idx_list [0, 2, 3, 1]
# reorder_sources [0, 3, 1, 2]
# shuffled_sources ['v1_1', 'src', 'v4', 'sparc']
# idx_list [3, 2, 1, 0]
# reorder_sources [3, 2, 1, 0]
# shuffled_sources ['src', 'sparc', 'v4', 'v1_1']
# idx_list [0, 2, 1, 3]
# reorder_sources [0, 2, 1, 3]
# shuffled_sources ['v1_1', 'sparc', 'v4', 'src']
# idx_list [1, 0, 3, 2]
# reorder_sources [1, 0, 3, 2]
# shuffled_sources ['v4', 'v1_1', 'src', 'sparc']
# idx_list [0, 2, 3, 1]
# reorder_sources [0, 3, 1, 2]
# shuffled_sources ['v1_1', 'src', 'v4', 'sparc']
# idx_list [2, 0, 1, 3]
# reorder_sources [1, 2, 0, 3]
# shuffled_sources ['v4', 'sparc', 'v1_1', 'src']
# idx_list [3, 0, 1, 2]
# reorder_sources [1, 2, 3, 0]
# shuffled_sources ['v4', 'sparc', 'src', 'v1_1']
# idx_list [1, 2, 3, 0]
# reorder_sources [3, 0, 1, 2]
# shuffled_sources ['src', 'v1_1', 'v4', 'sparc']
# idx_list [2, 3, 1, 0]
# reorder_sources [3, 2, 0, 1]
# shuffled_sources ['src', 'sparc', 'v1_1', 'v4']
# idx_list [0, 3, 1, 2]
# reorder_sources [0, 2, 3, 1]
# shuffled_sources ['v1_1', 'sparc', 'src', 'v4']
# idx_list [2, 1, 3, 0]
# reorder_sources [3, 1, 0, 2]
# shuffled_sources ['src', 'v4', 'v1_1', 'sparc']
# idx_list [0, 2, 1, 3]
# reorder_sources [0, 2, 1, 3]
# shuffled_sources ['v1_1', 'sparc', 'v4', 'src']
# idx_list [3, 1, 2, 0]
# reorder_sources [3, 1, 2, 0]
# shuffled_sources ['src', 'v4', 'sparc', 'v1_1']
# idx_list [3, 0, 1, 2]
# reorder_sources [1, 2, 3, 0]
# shuffled_sources ['v4', 'sparc', 'src', 'v1_1']
# idx_list [0, 2, 1, 3]
# reorder_sources [0, 2, 1, 3]
# shuffled_sources ['v1_1', 'sparc', 'v4', 'src']
# idx_list [1, 0, 3, 2]
# reorder_sources [1, 0, 3, 2]
# shuffled_sources ['v4', 'v1_1', 'src', 'sparc']
# idx_list [3, 0, 2, 1]
# reorder_sources [1, 3, 2, 0]
# shuffled_sources ['v4', 'src', 'sparc', 'v1_1']
# idx_list [0, 2, 3, 1]
# reorder_sources [0, 3, 1, 2]
# shuffled_sources ['v1_1', 'src', 'v4', 'sparc']
# idx_list [1, 0, 3, 2]
# reorder_sources [1, 0, 3, 2]
# shuffled_sources ['v4', 'v1_1', 'src', 'sparc']
# idx_list [0, 1, 2, 3]
# reorder_sources [0, 1, 2, 3]
# shuffled_sources ['v1_1', 'v4', 'sparc', 'src']
# idx_list [1, 0, 2, 3]
# reorder_sources [1, 0, 2, 3]
# shuffled_sources ['v4', 'v1_1', 'sparc', 'src']
# idx_list [2, 1, 0, 3]
# reorder_sources [2, 1, 0, 3]
# shuffled_sources ['sparc', 'v4', 'v1_1', 'src']
